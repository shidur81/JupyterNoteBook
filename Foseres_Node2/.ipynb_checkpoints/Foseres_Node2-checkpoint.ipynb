# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import collections
from collections import OrderedDict
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df_macro_fused_probempi = pd.read_csv("n2_fused_macro_probempi.csv")
df_macro_fused_nonprobempi = pd.read_csv("n2_fused_macro_nonprobempi.csv")
df_macro_newgeo_probempi = pd.read_csv("n2_newgeo_macro_probempi.csv")
df_macro_newgeo_nonprobempi = pd.read_csv("n2_newgeo_macro_nonprobempi.csv")
df_macro_nonfused_probempi = pd.read_csv("n2_nonfused_macro_probempi.csv")
df_macro_nonfused_nonprobempi = pd.read_csv("n2_nonfused_macro_nonprobempi.csv")

df_avx_fused_probmpi = pd.read_csv("n2_fused_avx_probempi.csv")
df_avx_fused_nonprobmpi = pd.read_csv("n2_fused_avx_nonprobempi.csv")
df_avx_newgeo_probempi = pd.read_csv("n2_newgeo_avx_probempi.csv")
df_avx_newgeo_nonprobempi = pd.read_csv("n2_newgeo_avx_nonprobempi.csv")
df_avx_nonfused_probempi = pd.read_csv("n2_nonfused_avx_probempi.csv")
df_avx_nonfused_nonprobempi = pd.read_csv("n2_nonfused_avx_nonprobempi.csv")

# %% [markdown]
# # MACRO CASES

# %% [markdown]
# ## 1. macro_fused_probempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_fused_probempi["N_Nodes"] = 2
df_macro_fused_probempi['NPX'] = (df_macro_fused_probempi.GLB_X//df_macro_fused_probempi.LOC_X)
df_macro_fused_probempi['NPY'] = (df_macro_fused_probempi.GLB_Y//df_macro_fused_probempi.LOC_Y)
df_macro_fused_probempi['NPZ'] = (df_macro_fused_probempi.GLB_Z//df_macro_fused_probempi.LOC_Z)
df_macro_fused_probempi['NPT'] = (df_macro_fused_probempi.GLB_T//df_macro_fused_probempi.LOC_T)
df_macro_fused_probempi["Total_proc"] = df_macro_fused_probempi["omp_thrd"]* df_macro_fused_probempi.MPI_size
# df_macro_fused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_fused_probempi_summary = df_macro_fused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_fused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacFusProb_16mpi_4omp = df_macro_fused_probempi[(df_macro_fused_probempi.omp_thrd == 4) & (df_macro_fused_probempi.GLB_T/df_macro_fused_probempi.LOC_T == 2) & (df_macro_fused_probempi.GLB_X/df_macro_fused_probempi.LOC_X == 2) & (df_macro_fused_probempi.GLB_Y/df_macro_fused_probempi.LOC_Y == 2)& (df_macro_fused_probempi.GLB_Z/df_macro_fused_probempi.LOC_Z == 2)]
dfMacFusProb_32mpi_2omp = df_macro_fused_probempi[(df_macro_fused_probempi.omp_thrd == 2) & (df_macro_fused_probempi.GLB_T/df_macro_fused_probempi.LOC_T == 4) & (df_macro_fused_probempi.GLB_X/df_macro_fused_probempi.LOC_X == 2) & (df_macro_fused_probempi.GLB_Y/df_macro_fused_probempi.LOC_Y == 2)& (df_macro_fused_probempi.GLB_Z/df_macro_fused_probempi.LOC_Z == 2)]
dfMacFusProb_56mpi_1omp = df_macro_fused_probempi[(df_macro_fused_probempi.omp_thrd == 1) & (df_macro_fused_probempi.GLB_T/df_macro_fused_probempi.LOC_T == 7) & (df_macro_fused_probempi.GLB_X/df_macro_fused_probempi.LOC_X == 2) & (df_macro_fused_probempi.GLB_Y/df_macro_fused_probempi.LOC_Y == 2)& (df_macro_fused_probempi.GLB_Z/df_macro_fused_probempi.LOC_Z == 2)]
dfMacFusProb_64mpi_1omp = df_macro_fused_probempi[(df_macro_fused_probempi.omp_thrd == 1) & (df_macro_fused_probempi.GLB_T/df_macro_fused_probempi.LOC_T == 8) & (df_macro_fused_probempi.GLB_X/df_macro_fused_probempi.LOC_X == 2) & (df_macro_fused_probempi.GLB_Y/df_macro_fused_probempi.LOC_Y == 2)& (df_macro_fused_probempi.GLB_Z/df_macro_fused_probempi.LOC_Z == 2)]

# %% [markdown]
# ## 2. macro_fused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_fused_nonprobempi["N_Nodes"] = 2
df_macro_fused_nonprobempi['NPX'] = (df_macro_fused_nonprobempi.GLB_X//df_macro_fused_nonprobempi.LOC_X)
df_macro_fused_nonprobempi['NPY'] = (df_macro_fused_nonprobempi.GLB_Y//df_macro_fused_nonprobempi.LOC_Y)
df_macro_fused_nonprobempi['NPZ'] = (df_macro_fused_nonprobempi.GLB_Z//df_macro_fused_nonprobempi.LOC_Z)
df_macro_fused_nonprobempi['NPT'] = (df_macro_fused_nonprobempi.GLB_T//df_macro_fused_nonprobempi.LOC_T)
df_macro_fused_nonprobempi["Total_proc"] = df_macro_fused_nonprobempi["omp_thrd"]* df_macro_fused_nonprobempi.MPI_size
# df_macro_fused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_fused_nonprobempi_summary =df_macro_fused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_fused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacFusNonProb_16mpi_4omp = df_macro_fused_nonprobempi[(df_macro_fused_nonprobempi.omp_thrd == 4) & (df_macro_fused_nonprobempi.GLB_T/df_macro_fused_nonprobempi.LOC_T == 2) & (df_macro_fused_nonprobempi.GLB_X/df_macro_fused_nonprobempi.LOC_X == 2) & (df_macro_fused_nonprobempi.GLB_Y/df_macro_fused_nonprobempi.LOC_Y == 2)& (df_macro_fused_nonprobempi.GLB_Z/df_macro_fused_nonprobempi.LOC_Z == 2)]
dfMacFusNonProb_32mpi_2omp = df_macro_fused_nonprobempi[(df_macro_fused_nonprobempi.omp_thrd == 2) & (df_macro_fused_nonprobempi.GLB_T/df_macro_fused_nonprobempi.LOC_T == 4) & (df_macro_fused_nonprobempi.GLB_X/df_macro_fused_nonprobempi.LOC_X == 2) & (df_macro_fused_nonprobempi.GLB_Y/df_macro_fused_nonprobempi.LOC_Y == 2)& (df_macro_fused_nonprobempi.GLB_Z/df_macro_fused_nonprobempi.LOC_Z == 2)]
dfMacFusnonProb_56mpi_1omp = df_macro_fused_nonprobempi[(df_macro_fused_nonprobempi.omp_thrd == 1) & (df_macro_fused_nonprobempi.GLB_T/df_macro_fused_nonprobempi.LOC_T == 7) & (df_macro_fused_nonprobempi.GLB_X/df_macro_fused_nonprobempi.LOC_X == 2) & (df_macro_fused_nonprobempi.GLB_Y/df_macro_fused_nonprobempi.LOC_Y == 2)& (df_macro_fused_nonprobempi.GLB_Z/df_macro_fused_nonprobempi.LOC_Z == 2)]
dfMacFusnonProb_64mpi_1omp = df_macro_fused_nonprobempi[(df_macro_fused_nonprobempi.omp_thrd == 1) & (df_macro_fused_nonprobempi.GLB_T/df_macro_fused_nonprobempi.LOC_T == 8) & (df_macro_fused_nonprobempi.GLB_X/df_macro_fused_nonprobempi.LOC_X == 2) & (df_macro_fused_nonprobempi.GLB_Y/df_macro_fused_nonprobempi.LOC_Y == 2)& (df_macro_fused_nonprobempi.GLB_Z/df_macro_fused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - macro fused: probempi vs nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusProb_16mpi_4omp.GFLOPS*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_16mpi_4omp.GFLOPS*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusProb_32mpi_2omp.GFLOPS*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_32mpi_2omp.GFLOPS*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_56mpi_1omp.GFLOPS*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfMacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_56mpi_1omp.GFLOPS*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfMacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_64mpi_1omp.GFLOPS*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_64mpi_1omp.GFLOPS*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro Fused: probempi vs nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="5a4b4045-ca23-4c6f-a154-50e002c6b336" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a4b4045-ca23-4c6f-a154-50e002c6b336")) {                    Plotly.newPlot(                        "5a4b4045-ca23-4c6f-a154-50e002c6b336",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## BANDWIDTH - macro fused: probempi vs nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusProb_16mpi_4omp.BAND*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_16mpi_4omp.BAND*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusProb_32mpi_2omp.BAND*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_32mpi_2omp.BAND*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_56mpi_1omp.BAND*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfMacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_56mpi_1omp.BAND*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfMacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_64mpi_1omp.BAND*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_64mpi_1omp.BAND*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro Fused: probempi vs nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="776a3d89-7850-4d92-9b47-748a62e926b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("776a3d89-7850-4d92-9b47-748a62e926b9")) {                    Plotly.newPlot(                        "776a3d89-7850-4d92-9b47-748a62e926b9",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ### 3. macro_nonfused_probempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_nonfused_probempi["N_Nodes"] = 2
df_macro_nonfused_probempi['NPX'] = (df_macro_nonfused_probempi.GLB_X//df_macro_nonfused_probempi.LOC_X)
df_macro_nonfused_probempi['NPY'] = (df_macro_nonfused_probempi.GLB_Y//df_macro_nonfused_probempi.LOC_Y)
df_macro_nonfused_probempi['NPZ'] = (df_macro_nonfused_probempi.GLB_Z//df_macro_nonfused_probempi.LOC_Z)
df_macro_nonfused_probempi['NPT'] = (df_macro_nonfused_probempi.GLB_T//df_macro_nonfused_probempi.LOC_T)
df_macro_nonfused_probempi["Total_proc"] = df_macro_nonfused_probempi["omp_thrd"]* df_macro_nonfused_probempi.MPI_size
# df_macro_nonfused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_nonfused_probempi_summary = df_macro_nonfused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_nonfused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacNonFusProb_16mpi_4omp = df_macro_nonfused_probempi[(df_macro_nonfused_probempi.omp_thrd == 4) & (df_macro_nonfused_probempi.GLB_T/df_macro_nonfused_probempi.LOC_T == 2) & (df_macro_nonfused_probempi.GLB_X/df_macro_nonfused_probempi.LOC_X == 2) & (df_macro_nonfused_probempi.GLB_Y/df_macro_nonfused_probempi.LOC_Y == 2)& (df_macro_nonfused_probempi.GLB_Z/df_macro_nonfused_probempi.LOC_Z == 2)]
dfMacNonFusProb_32mpi_2omp = df_macro_nonfused_probempi[(df_macro_nonfused_probempi.omp_thrd == 2) & (df_macro_nonfused_probempi.GLB_T/df_macro_nonfused_probempi.LOC_T == 4) & (df_macro_nonfused_probempi.GLB_X/df_macro_nonfused_probempi.LOC_X == 2) & (df_macro_nonfused_probempi.GLB_Y/df_macro_nonfused_probempi.LOC_Y == 2)& (df_macro_nonfused_probempi.GLB_Z/df_macro_nonfused_probempi.LOC_Z == 2)]
dfMacNonFusProb_56mpi_1omp = df_macro_nonfused_probempi[(df_macro_nonfused_probempi.omp_thrd == 1) & (df_macro_nonfused_probempi.GLB_T/df_macro_nonfused_probempi.LOC_T == 7) & (df_macro_nonfused_probempi.GLB_X/df_macro_nonfused_probempi.LOC_X == 2) & (df_macro_nonfused_probempi.GLB_Y/df_macro_nonfused_probempi.LOC_Y == 2)& (df_macro_nonfused_probempi.GLB_Z/df_macro_nonfused_probempi.LOC_Z == 2)]
dfMacNonFusProb_64mpi_1omp = df_macro_nonfused_probempi[(df_macro_nonfused_probempi.omp_thrd == 1) & (df_macro_nonfused_probempi.GLB_T/df_macro_nonfused_probempi.LOC_T == 8) & (df_macro_nonfused_probempi.GLB_X/df_macro_nonfused_probempi.LOC_X == 2) & (df_macro_nonfused_probempi.GLB_Y/df_macro_nonfused_probempi.LOC_Y == 2)& (df_macro_nonfused_probempi.GLB_Z/df_macro_nonfused_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 4. macro_nonfused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_nonfused_nonprobempi["N_Nodes"] = 2
df_macro_nonfused_nonprobempi['NPX'] = (df_macro_nonfused_nonprobempi.GLB_X//df_macro_nonfused_nonprobempi.LOC_X)
df_macro_nonfused_nonprobempi['NPY'] = (df_macro_nonfused_nonprobempi.GLB_Y//df_macro_nonfused_nonprobempi.LOC_Y)
df_macro_nonfused_nonprobempi['NPZ'] = (df_macro_nonfused_nonprobempi.GLB_Z//df_macro_nonfused_nonprobempi.LOC_Z)
df_macro_nonfused_nonprobempi['NPT'] = (df_macro_nonfused_nonprobempi.GLB_T//df_macro_nonfused_nonprobempi.LOC_T)
df_macro_nonfused_nonprobempi["Total_proc"] = df_macro_nonfused_nonprobempi["omp_thrd"]* df_macro_nonfused_nonprobempi.MPI_size
# df_macro_nonfused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_nonfused_nonprobempi_summary = df_macro_nonfused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_nonfused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacNonFusNonProb_16mpi_4omp = df_macro_nonfused_nonprobempi[(df_macro_nonfused_nonprobempi.omp_thrd == 4) & (df_macro_nonfused_nonprobempi.GLB_T/df_macro_nonfused_nonprobempi.LOC_T == 2) & (df_macro_nonfused_nonprobempi.GLB_X/df_macro_nonfused_nonprobempi.LOC_X == 2) & (df_macro_nonfused_nonprobempi.GLB_Y/df_macro_nonfused_nonprobempi.LOC_Y == 2)& (df_macro_nonfused_nonprobempi.GLB_Z/df_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfMacNonFusNonProb_32mpi_2omp = df_macro_nonfused_nonprobempi[(df_macro_nonfused_nonprobempi.omp_thrd == 2) & (df_macro_nonfused_nonprobempi.GLB_T/df_macro_nonfused_nonprobempi.LOC_T == 4) & (df_macro_nonfused_nonprobempi.GLB_X/df_macro_nonfused_nonprobempi.LOC_X == 2) & (df_macro_nonfused_nonprobempi.GLB_Y/df_macro_nonfused_nonprobempi.LOC_Y == 2)& (df_macro_nonfused_nonprobempi.GLB_Z/df_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfMacNonFusNonProb_56mpi_1omp = df_macro_nonfused_nonprobempi[(df_macro_nonfused_nonprobempi.omp_thrd == 1) & (df_macro_nonfused_nonprobempi.GLB_T/df_macro_nonfused_nonprobempi.LOC_T == 7) & (df_macro_nonfused_nonprobempi.GLB_X/df_macro_nonfused_nonprobempi.LOC_X == 2) & (df_macro_nonfused_nonprobempi.GLB_Y/df_macro_nonfused_nonprobempi.LOC_Y == 2)& (df_macro_nonfused_nonprobempi.GLB_Z/df_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfMacNonFusNonProb_64mpi_1omp = df_macro_nonfused_nonprobempi[(df_macro_nonfused_nonprobempi.omp_thrd == 1) & (df_macro_nonfused_nonprobempi.GLB_T/df_macro_nonfused_nonprobempi.LOC_T == 8) & (df_macro_nonfused_nonprobempi.GLB_X/df_macro_nonfused_nonprobempi.LOC_X == 2) & (df_macro_nonfused_nonprobempi.GLB_Y/df_macro_nonfused_nonprobempi.LOC_Y == 2)& (df_macro_nonfused_nonprobempi.GLB_Z/df_macro_nonfused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - Macro nonfused: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_16mpi_4omp.GFLOPS*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_16mpi_4omp.GFLOPS*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_32mpi_2omp.GFLOPS*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_32mpi_2omp.GFLOPS*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_56mpi_1omp.GFLOPS*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_56mpi_1omp.GFLOPS*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_64mpi_1omp.GFLOPS*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_64mpi_1omp.GFLOPS*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro nonfused: Probempi vs Nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="749a2ac6-d318-459d-a9dd-6660bdfbd947" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("749a2ac6-d318-459d-a9dd-6660bdfbd947")) {                    Plotly.newPlot(                        "749a2ac6-d318-459d-a9dd-6660bdfbd947",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - Macro nonfused: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_16mpi_4omp.BAND*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_16mpi_4omp.BAND*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_32mpi_2omp.BAND*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_32mpi_2omp.BAND*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_56mpi_1omp.BAND*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_56mpi_1omp.BAND*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_64mpi_1omp.BAND*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_64mpi_1omp.BAND*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro nonfused: Probempi vs Nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="828173ef-8148-4b2d-aa32-e6a3ddfbd41e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("828173ef-8148-4b2d-aa32-e6a3ddfbd41e")) {                    Plotly.newPlot(                        "828173ef-8148-4b2d-aa32-e6a3ddfbd41e",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ### 5. macro_newgeo_probempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_newgeo_probempi["N_Nodes"] = 2
df_macro_newgeo_probempi['NPX'] = (df_macro_newgeo_probempi.GLB_X//df_macro_newgeo_probempi.LOC_X)
df_macro_newgeo_probempi['NPY'] = (df_macro_newgeo_probempi.GLB_Y//df_macro_newgeo_probempi.LOC_Y)
df_macro_newgeo_probempi['NPZ'] = (df_macro_newgeo_probempi.GLB_Z//df_macro_newgeo_probempi.LOC_Z)
df_macro_newgeo_probempi['NPT'] = (df_macro_newgeo_probempi.GLB_T//df_macro_newgeo_probempi.LOC_T)
df_macro_newgeo_probempi["Total_proc"] = df_macro_newgeo_probempi["omp_thrd"]* df_macro_newgeo_probempi.MPI_size
# df_macro_newgeo_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_newgeo_probempi_summary =df_macro_newgeo_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_newgeo_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacNewgeoProb_16mpi_4omp = df_macro_newgeo_probempi[(df_macro_newgeo_probempi.omp_thrd == 4) & (df_macro_newgeo_probempi.GLB_T/df_macro_newgeo_probempi.LOC_T == 2) & (df_macro_newgeo_probempi.GLB_X/df_macro_newgeo_probempi.LOC_X == 2) & (df_macro_newgeo_probempi.GLB_Y/df_macro_newgeo_probempi.LOC_Y == 2)& (df_macro_newgeo_probempi.GLB_Z/df_macro_newgeo_probempi.LOC_Z == 2)]
dfMacNewgeoProb_32mpi_2omp = df_macro_newgeo_probempi[(df_macro_newgeo_probempi.omp_thrd == 2) & (df_macro_newgeo_probempi.GLB_T/df_macro_newgeo_probempi.LOC_T == 4) & (df_macro_newgeo_probempi.GLB_X/df_macro_newgeo_probempi.LOC_X == 2) & (df_macro_newgeo_probempi.GLB_Y/df_macro_newgeo_probempi.LOC_Y == 2)& (df_macro_newgeo_probempi.GLB_Z/df_macro_newgeo_probempi.LOC_Z == 2)]
dfMacNewgeoProb_56mpi_1omp = df_macro_newgeo_probempi[(df_macro_newgeo_probempi.omp_thrd == 1) & (df_macro_newgeo_probempi.GLB_T/df_macro_newgeo_probempi.LOC_T == 7) & (df_macro_newgeo_probempi.GLB_X/df_macro_newgeo_probempi.LOC_X == 2) & (df_macro_newgeo_probempi.GLB_Y/df_macro_newgeo_probempi.LOC_Y == 2)& (df_macro_newgeo_probempi.GLB_Z/df_macro_newgeo_probempi.LOC_Z == 2)]
dfMacNewgeoProb_64mpi_1omp = df_macro_newgeo_probempi[(df_macro_newgeo_probempi.omp_thrd == 1) & (df_macro_newgeo_probempi.GLB_T/df_macro_newgeo_probempi.LOC_T == 8) & (df_macro_newgeo_probempi.GLB_X/df_macro_newgeo_probempi.LOC_X == 2) & (df_macro_newgeo_probempi.GLB_Y/df_macro_newgeo_probempi.LOC_Y == 2)& (df_macro_newgeo_probempi.GLB_Z/df_macro_newgeo_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 6. macro_newgeo_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
df_macro_newgeo_nonprobempi["N_Nodes"] = 2
df_macro_newgeo_nonprobempi['NPX'] = (df_macro_newgeo_nonprobempi.GLB_X//df_macro_newgeo_nonprobempi.LOC_X)
df_macro_newgeo_nonprobempi['NPY'] = (df_macro_newgeo_nonprobempi.GLB_Y//df_macro_newgeo_nonprobempi.LOC_Y)
df_macro_newgeo_nonprobempi['NPZ'] = (df_macro_newgeo_nonprobempi.GLB_Z//df_macro_newgeo_nonprobempi.LOC_Z)
df_macro_newgeo_nonprobempi['NPT'] = (df_macro_newgeo_nonprobempi.GLB_T//df_macro_newgeo_nonprobempi.LOC_T)
df_macro_newgeo_nonprobempi["Total_proc"] = df_macro_newgeo_nonprobempi["omp_thrd"]* df_macro_newgeo_nonprobempi.MPI_size
# df_macro_newgeo_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_macro_newgeo_nonprobempi_summary = df_macro_newgeo_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_macro_newgeo_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfMacNewgeoNonProb_16mpi_4omp = df_macro_newgeo_nonprobempi[(df_macro_newgeo_nonprobempi.omp_thrd == 4) & (df_macro_newgeo_nonprobempi.GLB_T/df_macro_newgeo_nonprobempi.LOC_T == 2) & (df_macro_newgeo_nonprobempi.GLB_X/df_macro_newgeo_nonprobempi.LOC_X == 2) & (df_macro_newgeo_nonprobempi.GLB_Y/df_macro_newgeo_nonprobempi.LOC_Y == 2)& (df_macro_newgeo_nonprobempi.GLB_Z/df_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfMacNewgeoNonProb_32mpi_2omp = df_macro_newgeo_nonprobempi[(df_macro_newgeo_nonprobempi.omp_thrd == 2) & (df_macro_newgeo_nonprobempi.GLB_T/df_macro_newgeo_nonprobempi.LOC_T == 4) & (df_macro_newgeo_nonprobempi.GLB_X/df_macro_newgeo_nonprobempi.LOC_X == 2) & (df_macro_newgeo_nonprobempi.GLB_Y/df_macro_newgeo_nonprobempi.LOC_Y == 2)& (df_macro_newgeo_nonprobempi.GLB_Z/df_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfMacNewgeoNonProb_56mpi_1omp = df_macro_newgeo_nonprobempi[(df_macro_newgeo_nonprobempi.omp_thrd == 1) & (df_macro_newgeo_nonprobempi.GLB_T/df_macro_newgeo_nonprobempi.LOC_T == 7) & (df_macro_newgeo_nonprobempi.GLB_X/df_macro_newgeo_nonprobempi.LOC_X == 2) & (df_macro_newgeo_nonprobempi.GLB_Y/df_macro_newgeo_nonprobempi.LOC_Y == 2)& (df_macro_newgeo_nonprobempi.GLB_Z/df_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfMacNewgeoNonProb_64mpi_1omp = df_macro_newgeo_nonprobempi[(df_macro_newgeo_nonprobempi.omp_thrd == 1) & (df_macro_newgeo_nonprobempi.GLB_T/df_macro_newgeo_nonprobempi.LOC_T == 8) & (df_macro_newgeo_nonprobempi.GLB_X/df_macro_newgeo_nonprobempi.LOC_X == 2) & (df_macro_newgeo_nonprobempi.GLB_Y/df_macro_newgeo_nonprobempi.LOC_Y == 2)& (df_macro_newgeo_nonprobempi.GLB_Z/df_macro_newgeo_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - Macro Newgeometry: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_16mpi_4omp.GFLOPS*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_16mpi_4omp.GFLOPS*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_32mpi_2omp.GFLOPS*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_32mpi_2omp.GFLOPS*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_56mpi_1omp.GFLOPS*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_56mpi_1omp.GFLOPS*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_64mpi_1omp.GFLOPS*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_64mpi_1omp.GFLOPS*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                          line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro Newgeometry: Probempi vs Nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="2dfade67-ca60-4f73-bd82-f0989069bbb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dfade67-ca60-4f73-bd82-f0989069bbb2")) {                    Plotly.newPlot(                        "2dfade67-ca60-4f73-bd82-f0989069bbb2",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - Macro Newgeometry: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_16mpi_4omp.BAND*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_16mpi_4omp.BAND*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_32mpi_2omp.BAND*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_32mpi_2omp.BAND*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_56mpi_1omp.BAND*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_56mpi_1omp.BAND*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_64mpi_1omp.BAND*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_64mpi_1omp.BAND*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro Newgeometry: Probempi vs Nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="1f764945-7561-4d95-b86e-460833f8cf23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f764945-7561-4d95-b86e-460833f8cf23")) {                    Plotly.newPlot(                        "1f764945-7561-4d95-b86e-460833f8cf23",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # AVX CASES

# %% [markdown]
# ### 1. avx_fused_probmpi

# %% [markdown]
# ### Add Columns

# %%
df_avx_fused_probmpi["N_Nodes"] = 2
df_avx_fused_probmpi['NPX'] = (df_avx_fused_probmpi.GLB_X//df_avx_fused_probmpi.LOC_X)
df_avx_fused_probmpi['NPY'] = (df_avx_fused_probmpi.GLB_Y//df_avx_fused_probmpi.LOC_Y)
df_avx_fused_probmpi['NPZ'] = (df_avx_fused_probmpi.GLB_Z//df_avx_fused_probmpi.LOC_Z)
df_avx_fused_probmpi['NPT'] = (df_avx_fused_probmpi.GLB_T//df_avx_fused_probmpi.LOC_T)
df_avx_fused_probmpi["Total_proc"] = df_avx_fused_probmpi["omp_thrd"]* df_avx_fused_probmpi.MPI_size
# df_avx_fused_probmpi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_fused_probmpi_summary = df_avx_fused_probmpi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_fused_probmpi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxFusProb_16mpi_4omp = df_avx_fused_probmpi[(df_avx_fused_probmpi.omp_thrd == 4) & (df_avx_fused_probmpi.GLB_T/df_avx_fused_probmpi.LOC_T == 2) & (df_avx_fused_probmpi.GLB_X/df_avx_fused_probmpi.LOC_X == 2) & (df_avx_fused_probmpi.GLB_Y/df_avx_fused_probmpi.LOC_Y == 2)& (df_avx_fused_probmpi.GLB_Z/df_avx_fused_probmpi.LOC_Z == 2)]
dfAvxFusProb_32mpi_2omp = df_avx_fused_probmpi[(df_avx_fused_probmpi.omp_thrd == 2) & (df_avx_fused_probmpi.GLB_T/df_avx_fused_probmpi.LOC_T == 4) & (df_avx_fused_probmpi.GLB_X/df_avx_fused_probmpi.LOC_X == 2) & (df_avx_fused_probmpi.GLB_Y/df_avx_fused_probmpi.LOC_Y == 2)& (df_avx_fused_probmpi.GLB_Z/df_avx_fused_probmpi.LOC_Z == 2)]
dfAvxFusProb_56mpi_1omp = df_avx_fused_probmpi[(df_avx_fused_probmpi.omp_thrd == 1) & (df_avx_fused_probmpi.GLB_T/df_avx_fused_probmpi.LOC_T == 7) & (df_avx_fused_probmpi.GLB_X/df_avx_fused_probmpi.LOC_X == 2) & (df_avx_fused_probmpi.GLB_Y/df_avx_fused_probmpi.LOC_Y == 2)& (df_avx_fused_probmpi.GLB_Z/df_avx_fused_probmpi.LOC_Z == 2)]
dfAvxFusProb_64mpi_1omp = df_avx_fused_probmpi[(df_avx_fused_probmpi.omp_thrd == 1) & (df_avx_fused_probmpi.GLB_T/df_avx_fused_probmpi.LOC_T == 8) & (df_avx_fused_probmpi.GLB_X/df_avx_fused_probmpi.LOC_X == 2) & (df_avx_fused_probmpi.GLB_Y/df_avx_fused_probmpi.LOC_Y == 2)& (df_avx_fused_probmpi.GLB_Z/df_avx_fused_probmpi.LOC_Z == 2)]

# %% [markdown]
# ### 2. avx_fused_nonprobmpi

# %% [markdown]
# ### Add Columns

# %%
df_avx_fused_nonprobmpi["N_Nodes"] = 2
df_avx_fused_nonprobmpi['NPX'] = (df_avx_fused_nonprobmpi.GLB_X//df_avx_fused_nonprobmpi.LOC_X)
df_avx_fused_nonprobmpi['NPY'] = (df_avx_fused_nonprobmpi.GLB_Y//df_avx_fused_nonprobmpi.LOC_Y)
df_avx_fused_nonprobmpi['NPZ'] = (df_avx_fused_nonprobmpi.GLB_Z//df_avx_fused_nonprobmpi.LOC_Z)
df_avx_fused_nonprobmpi['NPT'] = (df_avx_fused_nonprobmpi.GLB_T//df_avx_fused_nonprobmpi.LOC_T)
df_avx_fused_nonprobmpi["Total_proc"] = df_avx_fused_nonprobmpi["omp_thrd"]* df_avx_fused_nonprobmpi.MPI_size
# df_avx_fused_nonprobmpi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_fused_nonprobmpi_summary = df_avx_fused_nonprobmpi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_fused_nonprobmpi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxFusNonProb_16mpi_4omp = df_avx_fused_nonprobmpi[(df_avx_fused_nonprobmpi.omp_thrd == 4) & (df_avx_fused_nonprobmpi.GLB_T/df_avx_fused_nonprobmpi.LOC_T == 2) & (df_avx_fused_nonprobmpi.GLB_X/df_avx_fused_nonprobmpi.LOC_X == 2) & (df_avx_fused_nonprobmpi.GLB_Y/df_avx_fused_nonprobmpi.LOC_Y == 2)& (df_avx_fused_nonprobmpi.GLB_Z/df_avx_fused_nonprobmpi.LOC_Z == 2)]
dfAvxFusNonProb_32mpi_2omp = df_avx_fused_nonprobmpi[(df_avx_fused_nonprobmpi.omp_thrd == 2) & (df_avx_fused_nonprobmpi.GLB_T/df_avx_fused_nonprobmpi.LOC_T == 4) & (df_avx_fused_nonprobmpi.GLB_X/df_avx_fused_nonprobmpi.LOC_X == 2) & (df_avx_fused_nonprobmpi.GLB_Y/df_avx_fused_nonprobmpi.LOC_Y == 2)& (df_avx_fused_nonprobmpi.GLB_Z/df_avx_fused_nonprobmpi.LOC_Z == 2)]
dfAvxFusNonProb_56mpi_1omp = df_avx_fused_nonprobmpi[(df_avx_fused_nonprobmpi.omp_thrd == 1) & (df_avx_fused_nonprobmpi.GLB_T/df_avx_fused_nonprobmpi.LOC_T == 7) & (df_avx_fused_nonprobmpi.GLB_X/df_avx_fused_nonprobmpi.LOC_X == 2) & (df_avx_fused_nonprobmpi.GLB_Y/df_avx_fused_nonprobmpi.LOC_Y == 2)& (df_avx_fused_nonprobmpi.GLB_Z/df_avx_fused_nonprobmpi.LOC_Z == 2)]
dfAvxFusNonProb_64mpi_1omp = df_avx_fused_nonprobmpi[(df_avx_fused_nonprobmpi.omp_thrd == 1) & (df_avx_fused_nonprobmpi.GLB_T/df_avx_fused_nonprobmpi.LOC_T == 8) & (df_avx_fused_nonprobmpi.GLB_X/df_avx_fused_nonprobmpi.LOC_X == 2) & (df_avx_fused_nonprobmpi.GLB_Y/df_avx_fused_nonprobmpi.LOC_Y == 2)& (df_avx_fused_nonprobmpi.GLB_Z/df_avx_fused_nonprobmpi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-Fused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusProb_16mpi_4omp.GFLOPS*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_16mpi_4omp.GFLOPS*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusProb_32mpi_2omp.GFLOPS*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_32mpi_2omp.GFLOPS*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_56mpi_1omp.GFLOPS*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_56mpi_1omp.GFLOPS*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_64mpi_1omp.GFLOPS*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_64mpi_1omp.GFLOPS*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-Fused: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="4e2e6db1-7821-42f9-b8d2-4e9b1a14c73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e2e6db1-7821-42f9-b8d2-4e9b1a14c73f")) {                    Plotly.newPlot(                        "4e2e6db1-7821-42f9-b8d2-4e9b1a14c73f",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.0
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-Fused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusProb_16mpi_4omp.BAND*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_16mpi_4omp.BAND*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusProb_32mpi_2omp.BAND*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_32mpi_2omp.BAND*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_56mpi_1omp.BAND*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_56mpi_1omp.BAND*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfAvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_64mpi_1omp.BAND*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_64mpi_1omp.BAND*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-Fused: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="365fab42-6ec0-4d85-a4d7-09e010fc8975" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("365fab42-6ec0-4d85-a4d7-09e010fc8975")) {                    Plotly.newPlot(                        "365fab42-6ec0-4d85-a4d7-09e010fc8975",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.0
# ...

# %% [markdown]
# ### 3. avx_nonfused_probempi

# %% [markdown]
# ### Add Columns

# %%
df_avx_nonfused_probempi["N_Nodes"] = 2
df_avx_nonfused_probempi['NPX'] = (df_avx_nonfused_probempi.GLB_X//df_avx_nonfused_probempi.LOC_X)
df_avx_nonfused_probempi['NPY'] = (df_avx_nonfused_probempi.GLB_Y//df_avx_nonfused_probempi.LOC_Y)
df_avx_nonfused_probempi['NPZ'] = (df_avx_nonfused_probempi.GLB_Z//df_avx_nonfused_probempi.LOC_Z)
df_avx_nonfused_probempi['NPT'] = (df_avx_nonfused_probempi.GLB_T//df_avx_nonfused_probempi.LOC_T)
df_avx_nonfused_probempi["Total_proc"] = df_avx_nonfused_probempi["omp_thrd"]* df_avx_nonfused_probempi.MPI_size
# df_avx_nonfused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_nonfused_probempi_summary = df_avx_nonfused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_nonfused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxNonFusProb_16mpi_4omp = df_avx_nonfused_probempi[(df_avx_nonfused_probempi.omp_thrd == 4) & (df_avx_nonfused_probempi.GLB_T/df_avx_nonfused_probempi.LOC_T == 2) & (df_avx_nonfused_probempi.GLB_X/df_avx_nonfused_probempi.LOC_X == 2) & (df_avx_nonfused_probempi.GLB_Y/df_avx_nonfused_probempi.LOC_Y == 2)& (df_avx_nonfused_probempi.GLB_Z/df_avx_nonfused_probempi.LOC_Z == 2)]
dfAvxNonFusProb_32mpi_2omp = df_avx_nonfused_probempi[(df_avx_nonfused_probempi.omp_thrd == 2) & (df_avx_nonfused_probempi.GLB_T/df_avx_nonfused_probempi.LOC_T == 4) & (df_avx_nonfused_probempi.GLB_X/df_avx_nonfused_probempi.LOC_X == 2) & (df_avx_nonfused_probempi.GLB_Y/df_avx_nonfused_probempi.LOC_Y == 2)& (df_avx_nonfused_probempi.GLB_Z/df_avx_nonfused_probempi.LOC_Z == 2)]
dfAvxNonFusProb_56mpi_1omp = df_avx_nonfused_probempi[(df_avx_nonfused_probempi.omp_thrd == 1) & (df_avx_nonfused_probempi.GLB_T/df_avx_nonfused_probempi.LOC_T == 7) & (df_avx_nonfused_probempi.GLB_X/df_avx_nonfused_probempi.LOC_X == 2) & (df_avx_nonfused_probempi.GLB_Y/df_avx_nonfused_probempi.LOC_Y == 2)& (df_avx_nonfused_probempi.GLB_Z/df_avx_nonfused_probempi.LOC_Z == 2)]
dfAvxNonFusProb_64mpi_1omp = df_avx_nonfused_probempi[(df_avx_nonfused_probempi.omp_thrd == 1) & (df_avx_nonfused_probempi.GLB_T/df_avx_nonfused_probempi.LOC_T == 8) & (df_avx_nonfused_probempi.GLB_X/df_avx_nonfused_probempi.LOC_X == 2) & (df_avx_nonfused_probempi.GLB_Y/df_avx_nonfused_probempi.LOC_Y == 2)& (df_avx_nonfused_probempi.GLB_Z/df_avx_nonfused_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 4. avx_nonfused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
df_avx_nonfused_nonprobempi["N_Nodes"] = 2
df_avx_nonfused_nonprobempi['NPX'] = (df_avx_nonfused_nonprobempi.GLB_X//df_avx_nonfused_nonprobempi.LOC_X)
df_avx_nonfused_nonprobempi['NPY'] = (df_avx_nonfused_nonprobempi.GLB_Y//df_avx_nonfused_nonprobempi.LOC_Y)
df_avx_nonfused_nonprobempi['NPZ'] = (df_avx_nonfused_nonprobempi.GLB_Z//df_avx_nonfused_nonprobempi.LOC_Z)
df_avx_nonfused_nonprobempi['NPT'] = (df_avx_nonfused_nonprobempi.GLB_T//df_avx_nonfused_nonprobempi.LOC_T)
df_avx_nonfused_nonprobempi["Total_proc"] = df_avx_nonfused_nonprobempi["omp_thrd"]* df_avx_nonfused_nonprobempi.MPI_size
# df_avx_nonfused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_nonfused_nonprobempi_summary = df_avx_nonfused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_nonfused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxNonFusNonProb_16mpi_4omp = df_avx_nonfused_nonprobempi[(df_avx_nonfused_nonprobempi.omp_thrd == 4) & (df_avx_nonfused_nonprobempi.GLB_T/df_avx_nonfused_nonprobempi.LOC_T == 2) & (df_avx_nonfused_nonprobempi.GLB_X/df_avx_nonfused_nonprobempi.LOC_X == 2) & (df_avx_nonfused_nonprobempi.GLB_Y/df_avx_nonfused_nonprobempi.LOC_Y == 2)& (df_avx_nonfused_nonprobempi.GLB_Z/df_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfAvxNonFusNonProb_32mpi_2omp = df_avx_nonfused_nonprobempi[(df_avx_nonfused_nonprobempi.omp_thrd == 2) & (df_avx_nonfused_nonprobempi.GLB_T/df_avx_nonfused_nonprobempi.LOC_T == 4) & (df_avx_nonfused_nonprobempi.GLB_X/df_avx_nonfused_nonprobempi.LOC_X == 2) & (df_avx_nonfused_nonprobempi.GLB_Y/df_avx_nonfused_nonprobempi.LOC_Y == 2)& (df_avx_nonfused_nonprobempi.GLB_Z/df_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfAvxNonFusNonProb_56mpi_1omp = df_avx_nonfused_nonprobempi[(df_avx_nonfused_nonprobempi.omp_thrd == 1) & (df_avx_nonfused_nonprobempi.GLB_T/df_avx_nonfused_nonprobempi.LOC_T == 7) & (df_avx_nonfused_nonprobempi.GLB_X/df_avx_nonfused_nonprobempi.LOC_X == 2) & (df_avx_nonfused_nonprobempi.GLB_Y/df_avx_nonfused_nonprobempi.LOC_Y == 2)& (df_avx_nonfused_nonprobempi.GLB_Z/df_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfAvxNonFusNonProb_64mpi_1omp = df_avx_nonfused_nonprobempi[(df_avx_nonfused_nonprobempi.omp_thrd == 1) & (df_avx_nonfused_nonprobempi.GLB_T/df_avx_nonfused_nonprobempi.LOC_T == 8) & (df_avx_nonfused_nonprobempi.GLB_X/df_avx_nonfused_nonprobempi.LOC_X == 2) & (df_avx_nonfused_nonprobempi.GLB_Y/df_avx_nonfused_nonprobempi.LOC_Y == 2)& (df_avx_nonfused_nonprobempi.GLB_Z/df_avx_nonfused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-NonFused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_16mpi_4omp.GFLOPS*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_16mpi_4omp.GFLOPS*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_32mpi_2omp.GFLOPS*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_32mpi_2omp.GFLOPS*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_56mpi_1omp.GFLOPS*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_56mpi_1omp.GFLOPS*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_64mpi_1omp.GFLOPS*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_64mpi_1omp.GFLOPS*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))




# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-NonFused: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="80a456a2-a461-4361-b1d2-3965e2434546" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80a456a2-a461-4361-b1d2-3965e2434546")) {                    Plotly.newPlot(                        "80a456a2-a461-4361-b1d2-3965e2434546",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-NonFused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_16mpi_4omp.BAND*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_16mpi_4omp.BAND*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_32mpi_2omp.BAND*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_32mpi_2omp.BAND*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_56mpi_1omp.BAND*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_56mpi_1omp.BAND*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_64mpi_1omp.BAND*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_64mpi_1omp.BAND*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-NonFused: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="cea76c34-e06b-4ff7-bdd7-51dc6d0eb6f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cea76c34-e06b-4ff7-bdd7-51dc6d0eb6f3")) {                    Plotly.newPlot(                        "cea76c34-e06b-4ff7-bdd7-51dc6d0eb6f3",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ### 5. avx_newgeo_probempi

# %% [markdown]
# ### Add Columns

# %%
df_avx_newgeo_probempi["N_Nodes"] = 2
df_avx_newgeo_probempi['NPX'] = (df_avx_newgeo_probempi.GLB_X//df_avx_newgeo_probempi.LOC_X)
df_avx_newgeo_probempi['NPY'] = (df_avx_newgeo_probempi.GLB_Y//df_avx_newgeo_probempi.LOC_Y)
df_avx_newgeo_probempi['NPZ'] = (df_avx_newgeo_probempi.GLB_Z//df_avx_newgeo_probempi.LOC_Z)
df_avx_newgeo_probempi['NPT'] = (df_avx_newgeo_probempi.GLB_T//df_avx_newgeo_probempi.LOC_T)
df_avx_newgeo_probempi["Total_proc"] = df_avx_newgeo_probempi["omp_thrd"]* df_avx_newgeo_probempi.MPI_size
# df_avx_newgeo_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_newgeo_probempi_summary = df_avx_newgeo_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_newgeo_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxNewgeoProb_16mpi_4omp = df_avx_newgeo_probempi[(df_avx_newgeo_probempi.omp_thrd == 4) & (df_avx_newgeo_probempi.GLB_T/df_avx_newgeo_probempi.LOC_T == 2) & (df_avx_newgeo_probempi.GLB_X/df_avx_newgeo_probempi.LOC_X == 2) & (df_avx_newgeo_probempi.GLB_Y/df_avx_newgeo_probempi.LOC_Y == 2)& (df_avx_newgeo_probempi.GLB_Z/df_avx_newgeo_probempi.LOC_Z == 2)]
dfAvxNewgeoProb_32mpi_2omp = df_avx_newgeo_probempi[(df_avx_newgeo_probempi.omp_thrd == 2) & (df_avx_newgeo_probempi.GLB_T/df_avx_newgeo_probempi.LOC_T == 4) & (df_avx_newgeo_probempi.GLB_X/df_avx_newgeo_probempi.LOC_X == 2) & (df_avx_newgeo_probempi.GLB_Y/df_avx_newgeo_probempi.LOC_Y == 2)& (df_avx_newgeo_probempi.GLB_Z/df_avx_newgeo_probempi.LOC_Z == 2)]
dfAvxNewgeoProb_56mpi_1omp = df_avx_newgeo_probempi[(df_avx_newgeo_probempi.omp_thrd == 1) & (df_avx_newgeo_probempi.GLB_T/df_avx_newgeo_probempi.LOC_T == 7) & (df_avx_newgeo_probempi.GLB_X/df_avx_newgeo_probempi.LOC_X == 2) & (df_avx_newgeo_probempi.GLB_Y/df_avx_newgeo_probempi.LOC_Y == 2)& (df_avx_newgeo_probempi.GLB_Z/df_avx_newgeo_probempi.LOC_Z == 2)]
dfAvxNewgeoProb_64mpi_1omp = df_avx_newgeo_probempi[(df_avx_newgeo_probempi.omp_thrd == 1) & (df_avx_newgeo_probempi.GLB_T/df_avx_newgeo_probempi.LOC_T == 8) & (df_avx_newgeo_probempi.GLB_X/df_avx_newgeo_probempi.LOC_X == 2) & (df_avx_newgeo_probempi.GLB_Y/df_avx_newgeo_probempi.LOC_Y == 2)& (df_avx_newgeo_probempi.GLB_Z/df_avx_newgeo_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 6. avx_newgeo_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
df_avx_newgeo_nonprobempi["N_Nodes"] = 2
df_avx_newgeo_nonprobempi['NPX'] = (df_avx_newgeo_nonprobempi.GLB_X//df_avx_newgeo_nonprobempi.LOC_X)
df_avx_newgeo_nonprobempi['NPY'] = (df_avx_newgeo_nonprobempi.GLB_Y//df_avx_newgeo_nonprobempi.LOC_Y)
df_avx_newgeo_nonprobempi['NPZ'] = (df_avx_newgeo_nonprobempi.GLB_Z//df_avx_newgeo_nonprobempi.LOC_Z)
df_avx_newgeo_nonprobempi['NPT'] = (df_avx_newgeo_nonprobempi.GLB_T//df_avx_newgeo_nonprobempi.LOC_T)
df_avx_newgeo_nonprobempi["Total_proc"] = df_avx_newgeo_nonprobempi["omp_thrd"]* df_avx_newgeo_nonprobempi.MPI_size
# df_avx_newgeo_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
df_avx_newgeo_nonprobempi_summary = df_avx_newgeo_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
df_avx_newgeo_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfAvxNewgeoNonProb_16mpi_4omp = df_avx_newgeo_nonprobempi[(df_avx_newgeo_nonprobempi.omp_thrd == 4) & (df_avx_newgeo_nonprobempi.GLB_T/df_avx_newgeo_nonprobempi.LOC_T == 2) & (df_avx_newgeo_nonprobempi.GLB_X/df_avx_newgeo_nonprobempi.LOC_X == 2) & (df_avx_newgeo_nonprobempi.GLB_Y/df_avx_newgeo_nonprobempi.LOC_Y == 2)& (df_avx_newgeo_nonprobempi.GLB_Z/df_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfAvxNewgeoNonProb_32mpi_2omp = df_avx_newgeo_nonprobempi[(df_avx_newgeo_nonprobempi.omp_thrd == 2) & (df_avx_newgeo_nonprobempi.GLB_T/df_avx_newgeo_nonprobempi.LOC_T == 4) & (df_avx_newgeo_nonprobempi.GLB_X/df_avx_newgeo_nonprobempi.LOC_X == 2) & (df_avx_newgeo_nonprobempi.GLB_Y/df_avx_newgeo_nonprobempi.LOC_Y == 2)& (df_avx_newgeo_nonprobempi.GLB_Z/df_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfAvxNewgeoNonProb_56mpi_1omp = df_avx_newgeo_nonprobempi[(df_avx_newgeo_nonprobempi.omp_thrd == 1) & (df_avx_newgeo_nonprobempi.GLB_T/df_avx_newgeo_nonprobempi.LOC_T == 7) & (df_avx_newgeo_nonprobempi.GLB_X/df_avx_newgeo_nonprobempi.LOC_X == 2) & (df_avx_newgeo_nonprobempi.GLB_Y/df_avx_newgeo_nonprobempi.LOC_Y == 2)& (df_avx_newgeo_nonprobempi.GLB_Z/df_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfAvxNewgeoNonProb_64mpi_1omp = df_avx_newgeo_nonprobempi[(df_avx_newgeo_nonprobempi.omp_thrd == 1) & (df_avx_newgeo_nonprobempi.GLB_T/df_avx_newgeo_nonprobempi.LOC_T == 8) & (df_avx_newgeo_nonprobempi.GLB_X/df_avx_newgeo_nonprobempi.LOC_X == 2) & (df_avx_newgeo_nonprobempi.GLB_Y/df_avx_newgeo_nonprobempi.LOC_Y == 2)& (df_avx_newgeo_nonprobempi.GLB_Z/df_avx_newgeo_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-Newgeo: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_16mpi_4omp.GFLOPS*(dfAvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_16mpi_4omp.GFLOPS*(dfAvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_8mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_32mpi_2omp.GFLOPS*(dfAvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_32mpi_2omp.GFLOPS*(dfAvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_56mpi_1omp.GFLOPS*(dfAvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_56mpi_1omp.GFLOPS*(dfAvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_64mpi_1omp.GFLOPS*(dfAvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_64mpi_1omp.GFLOPS*(dfAvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-Newgeo: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="ed46bfc7-fc43-4c30-bad7-57f1b47de3be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed46bfc7-fc43-4c30-bad7-57f1b47de3be")) {                    Plotly.newPlot(                        "ed46bfc7-fc43-4c30-bad7-57f1b47de3be",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-Newgeo: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_16mpi_4omp.BAND*(dfAvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_16mpi_4omp.BAND*(dfAvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_32mpi_2omp.BAND*(dfAvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_32mpi_2omp.BAND*(dfAvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_56mpi_1omp.BAND*(dfAvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_56mpi_1omp.BAND*(dfAvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfAvxNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoProb_64mpi_1omp.BAND*(dfAvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNewgeoNonProb_64mpi_1omp.BAND*(dfAvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-Newgeo: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="9d60069e-de99-4e8f-8307-689799a060b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d60069e-de99-4e8f-8307-689799a060b8")) {                    Plotly.newPlot(                        "9d60069e-de99-4e8f-8307-689799a060b8",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # Comparisons

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusProb_16mpi_4omp.GFLOPS*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusProb_16mpi_4omp.GFLOPS*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusProb_32mpi_2omp.GFLOPS*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusProb_32mpi_2omp.GFLOPS*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_56mpi_1omp.GFLOPS*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_56mpi_1omp.GFLOPS*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_64mpi_1omp.GFLOPS*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_64mpi_1omp.GFLOPS*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))




# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="fb622faf-44fb-4efb-b9d1-0d5f15eb5439" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb622faf-44fb-4efb-b9d1-0d5f15eb5439")) {                    Plotly.newPlot(                        "fb622faf-44fb-4efb-b9d1-0d5f15eb5439",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (Probempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusProb_16mpi_4omp.BAND*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusProb_16mpi_4omp.BAND*(dfAvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusProb_32mpi_2omp.BAND*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusProb_32mpi_2omp.BAND*(dfAvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_56mpi_1omp.BAND*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_56mpi_1omp.BAND*(dfAvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_64mpi_1omp.BAND*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusProb_64mpi_1omp.BAND*(dfAvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Probempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="45131730-f163-4046-8e82-97d1dbad26cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45131730-f163-4046-8e82-97d1dbad26cd")) {                    Plotly.newPlot(                        "45131730-f163-4046-8e82-97d1dbad26cd",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (NonProbempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_16mpi_4omp.GFLOPS*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_16mpi_4omp.GFLOPS*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_32mpi_2omp.GFLOPS*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_32mpi_2omp.GFLOPS*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfMacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_56mpi_1omp.GFLOPS*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_56mpi_1omp.GFLOPS*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfMacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_64mpi_1omp.GFLOPS*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_64mpi_1omp.GFLOPS*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Non-Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="4f14daa3-fd50-4233-923d-feef72c738e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f14daa3-fd50-4233-923d-feef72c738e3")) {                    Plotly.newPlot(                        "4f14daa3-fd50-4233-923d-feef72c738e3",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (NonProbempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_16mpi_4omp.BAND*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_16mpi_4omp.BAND*(dfAvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_32mpi_2omp.BAND*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_32mpi_2omp.BAND*(dfAvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfMacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_56mpi_1omp.BAND*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_56mpi_1omp.BAND*(dfAvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfMacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_64mpi_1omp.BAND*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxFusNonProb_64mpi_1omp.BAND*(dfAvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-Fused vs AVX-Fused (NonProbempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="aeac24e4-7859-480f-8836-49d1a389354d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeac24e4-7859-480f-8836-49d1a389354d")) {                    Plotly.newPlot(                        "aeac24e4-7859-480f-8836-49d1a389354d",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # MACRO-Non-Fused vs AVX-Non-Fused

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_16mpi_4omp.GFLOPS*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_16mpi_4omp.GFLOPS*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))




# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_32mpi_2omp.GFLOPS*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_32mpi_2omp.GFLOPS*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_56mpi_1omp.GFLOPS*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_56mpi_1omp.GFLOPS*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_64mpi_1omp.GFLOPS*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_64mpi_1omp.GFLOPS*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="7dc5e75a-9d52-411f-b5eb-d6ed4535d912" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dc5e75a-9d52-411f-b5eb-d6ed4535d912")) {                    Plotly.newPlot(                        "7dc5e75a-9d52-411f-b5eb-d6ed4535d912",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523215
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (Probempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_16mpi_4omp.BAND*(dfMacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_16mpi_4omp.BAND*(dfAvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_32mpi_2omp.BAND*(dfMacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_32mpi_2omp.BAND*(dfAvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_56mpi_1omp.BAND*(dfMacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_56mpi_1omp.BAND*(dfAvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusProb_64mpi_1omp.BAND*(dfMacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfAvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusProb_64mpi_1omp.BAND*(dfAvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (Probempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="ef455924-2347-4de9-b5e0-770512bc0a3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef455924-2347-4de9-b5e0-770512bc0a3d")) {                    Plotly.newPlot(                        "ef455924-2347-4de9-b5e0-770512bc0a3d",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523215
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (NonProbempi): GFLOPS

# %%
fig = go.Figure()

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_16mpi_4omp.GFLOPS*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_16mpi_4omp.GFLOPS*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_32mpi_2omp.GFLOPS*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_32mpi_2omp.GFLOPS*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))





# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_56mpi_1omp.GFLOPS*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_56mpi_1omp.GFLOPS*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_64mpi_1omp.GFLOPS*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_64mpi_1omp.GFLOPS*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))





# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (NonProbempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="f5a90a59-ac9b-4155-a4e8-2bcf71852ff3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5a90a59-ac9b-4155-a4e8-2bcf71852ff3")) {                    Plotly.newPlot(                        "f5a90a59-ac9b-4155-a4e8-2bcf71852ff3",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (NonProbempi): BANDWIDTH

# %%
fig = go.Figure()

# 1----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_16mpi_4omp.BAND*(dfMacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_16mpi_4omp.BAND*(dfAvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_32mpi_2omp.BAND*(dfMacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_32mpi_2omp.BAND*(dfAvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))



# 3----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_56mpi_1omp.BAND*(dfMacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_56mpi_1omp.BAND*(dfAvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfMacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNonFusNonProb_64mpi_1omp.GFLOPS*(dfMacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfAvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfAvxNonFusNonProb_64mpi_1omp.BAND*(dfAvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (NonProbempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="28bbaa20-0550-4087-9b71-ada4cbbea519" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28bbaa20-0550-4087-9b71-ada4cbbea519")) {                    Plotly.newPlot(                        "28bbaa20-0550-4087-9b71-ada4cbbea519",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (NonProbempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_16mpi_4omp.GFLOPS*(dfMacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_16mpi_4omp.GFLOPS*(dfMacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfMacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusNonProb_32mpi_2omp.GFLOPS*(dfMacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_32mpi_2omp.GFLOPS*(dfMacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))



# 3----


fig.add_trace(go.Scatter(x=(dfMacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_56mpi_1omp.GFLOPS*(dfMacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))
fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_56mpi_1omp.GFLOPS*(dfMacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----

fig.add_trace(go.Scatter(x=(dfMacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusnonProb_64mpi_1omp.GFLOPS*(dfMacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoNonProb_64mpi_1omp.GFLOPS*(dfMacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                          line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (NonProbempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="8f4a6b5f-b705-4d93-92c4-00d434f3ae72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f4a6b5f-b705-4d93-92c4-00d434f3ae72")) {                    Plotly.newPlot(                        "8f4a6b5f-b705-4d93-92c4-00d434f3ae72",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfMacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacFusProb_16mpi_4omp.GFLOPS*(dfMacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_16mpi_4omp.GFLOPS*(dfMacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----

fig.add_trace(go.Scatter(x=(dfMacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacFusProb_32mpi_2omp.GFLOPS*(dfMacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_32mpi_2omp.GFLOPS*(dfMacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))




# 3----
fig.add_trace(go.Scatter(x=(dfMacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_56mpi_1omp.GFLOPS*(dfMacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_56mpi_1omp.GFLOPS*(dfMacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))




# 4----
fig.add_trace(go.Scatter(x=(dfMacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacFusProb_64mpi_1omp.GFLOPS*(dfMacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))
fig.add_trace(go.Scatter(x=(dfMacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfMacNewgeoProb_64mpi_1omp.GFLOPS*(dfMacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"))
# Out:
# <div>                            <div id="c1c838ca-eaa5-4604-a9be-53188e988cea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1c838ca-eaa5-4604-a9be-53188e988cea")) {                    Plotly.newPlot(                        "c1c838ca-eaa5-4604-a9be-53188e988cea",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...
