# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import collections
from collections import OrderedDict
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

dfn2_macro_fused_probempi = pd.read_csv("n2_fused_macro_probempi.csv")
dfn2_macro_fused_nonprobempi = pd.read_csv("n2_fused_macro_nonprobempi.csv")
dfn2_macro_newgeo_probempi = pd.read_csv("n2_newgeo_macro_probempi.csv")
dfn2_macro_newgeo_nonprobempi = pd.read_csv("n2_newgeo_macro_nonprobempi.csv")
dfn2_macro_nonfused_probempi = pd.read_csv("n2_nonfused_macro_probempi.csv")
dfn2_macro_nonfused_nonprobempi = pd.read_csv("n2_nonfused_macro_nonprobempi.csv")

dfn2_avx_fused_probmpi = pd.read_csv("n2_fused_avx_probempi.csv")
dfn2_avx_fused_nonprobmpi = pd.read_csv("n2_fused_avx_nonprobempi.csv")
dfn2_avx_newgeo_probempi = pd.read_csv("n2_newgeo_avx_probempi.csv")
dfn2_avx_newgeo_nonprobempi = pd.read_csv("n2_newgeo_avx_nonprobempi.csv")
dfn2_avx_nonfused_probempi = pd.read_csv("n2_nonfused_avx_probempi.csv")
dfn2_avx_nonfused_nonprobempi = pd.read_csv("n2_nonfused_avx_nonprobempi.csv")

# %% [markdown]
# # MACRO CASES

# %% [markdown]
# ## 1. macro_fused_probempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_fused_probempi["N_Nodes"] = 2
dfn2_macro_fused_probempi['NPX'] = (dfn2_macro_fused_probempi.GLB_X//dfn2_macro_fused_probempi.LOC_X)
dfn2_macro_fused_probempi['NPY'] = (dfn2_macro_fused_probempi.GLB_Y//dfn2_macro_fused_probempi.LOC_Y)
dfn2_macro_fused_probempi['NPZ'] = (dfn2_macro_fused_probempi.GLB_Z//dfn2_macro_fused_probempi.LOC_Z)
dfn2_macro_fused_probempi['NPT'] = (dfn2_macro_fused_probempi.GLB_T//dfn2_macro_fused_probempi.LOC_T)
dfn2_macro_fused_probempi["Total_proc"] = dfn2_macro_fused_probempi["omp_thrd"]* dfn2_macro_fused_probempi.MPI_size
# dfn2_macro_fused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_fused_probempi_summary = dfn2_macro_fused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_fused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacFusProb_16mpi_4omp = dfn2_macro_fused_probempi[(dfn2_macro_fused_probempi.omp_thrd == 4) & (dfn2_macro_fused_probempi.GLB_T/dfn2_macro_fused_probempi.LOC_T == 2) & (dfn2_macro_fused_probempi.GLB_X/dfn2_macro_fused_probempi.LOC_X == 2) & (dfn2_macro_fused_probempi.GLB_Y/dfn2_macro_fused_probempi.LOC_Y == 2)& (dfn2_macro_fused_probempi.GLB_Z/dfn2_macro_fused_probempi.LOC_Z == 2)]
dfn2MacFusProb_32mpi_2omp = dfn2_macro_fused_probempi[(dfn2_macro_fused_probempi.omp_thrd == 2) & (dfn2_macro_fused_probempi.GLB_T/dfn2_macro_fused_probempi.LOC_T == 4) & (dfn2_macro_fused_probempi.GLB_X/dfn2_macro_fused_probempi.LOC_X == 2) & (dfn2_macro_fused_probempi.GLB_Y/dfn2_macro_fused_probempi.LOC_Y == 2)& (dfn2_macro_fused_probempi.GLB_Z/dfn2_macro_fused_probempi.LOC_Z == 2)]
dfn2MacFusProb_56mpi_1omp = dfn2_macro_fused_probempi[(dfn2_macro_fused_probempi.omp_thrd == 1) & (dfn2_macro_fused_probempi.GLB_T/dfn2_macro_fused_probempi.LOC_T == 7) & (dfn2_macro_fused_probempi.GLB_X/dfn2_macro_fused_probempi.LOC_X == 2) & (dfn2_macro_fused_probempi.GLB_Y/dfn2_macro_fused_probempi.LOC_Y == 2)& (dfn2_macro_fused_probempi.GLB_Z/dfn2_macro_fused_probempi.LOC_Z == 2)]
dfn2MacFusProb_64mpi_1omp = dfn2_macro_fused_probempi[(dfn2_macro_fused_probempi.omp_thrd == 1) & (dfn2_macro_fused_probempi.GLB_T/dfn2_macro_fused_probempi.LOC_T == 8) & (dfn2_macro_fused_probempi.GLB_X/dfn2_macro_fused_probempi.LOC_X == 2) & (dfn2_macro_fused_probempi.GLB_Y/dfn2_macro_fused_probempi.LOC_Y == 2)& (dfn2_macro_fused_probempi.GLB_Z/dfn2_macro_fused_probempi.LOC_Z == 2)]

# %% [markdown]
# ## 2. macro_fused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_fused_nonprobempi["N_Nodes"] = 2
dfn2_macro_fused_nonprobempi['NPX'] = (dfn2_macro_fused_nonprobempi.GLB_X//dfn2_macro_fused_nonprobempi.LOC_X)
dfn2_macro_fused_nonprobempi['NPY'] = (dfn2_macro_fused_nonprobempi.GLB_Y//dfn2_macro_fused_nonprobempi.LOC_Y)
dfn2_macro_fused_nonprobempi['NPZ'] = (dfn2_macro_fused_nonprobempi.GLB_Z//dfn2_macro_fused_nonprobempi.LOC_Z)
dfn2_macro_fused_nonprobempi['NPT'] = (dfn2_macro_fused_nonprobempi.GLB_T//dfn2_macro_fused_nonprobempi.LOC_T)
dfn2_macro_fused_nonprobempi["Total_proc"] = dfn2_macro_fused_nonprobempi["omp_thrd"]* dfn2_macro_fused_nonprobempi.MPI_size
# dfn2_macro_fused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_fused_nonprobempi_summary =dfn2_macro_fused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_fused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacFusNonProb_16mpi_4omp = dfn2_macro_fused_nonprobempi[(dfn2_macro_fused_nonprobempi.omp_thrd == 4) & (dfn2_macro_fused_nonprobempi.GLB_T/dfn2_macro_fused_nonprobempi.LOC_T == 2) & (dfn2_macro_fused_nonprobempi.GLB_X/dfn2_macro_fused_nonprobempi.LOC_X == 2) & (dfn2_macro_fused_nonprobempi.GLB_Y/dfn2_macro_fused_nonprobempi.LOC_Y == 2)& (dfn2_macro_fused_nonprobempi.GLB_Z/dfn2_macro_fused_nonprobempi.LOC_Z == 2)]
dfn2MacFusNonProb_32mpi_2omp = dfn2_macro_fused_nonprobempi[(dfn2_macro_fused_nonprobempi.omp_thrd == 2) & (dfn2_macro_fused_nonprobempi.GLB_T/dfn2_macro_fused_nonprobempi.LOC_T == 4) & (dfn2_macro_fused_nonprobempi.GLB_X/dfn2_macro_fused_nonprobempi.LOC_X == 2) & (dfn2_macro_fused_nonprobempi.GLB_Y/dfn2_macro_fused_nonprobempi.LOC_Y == 2)& (dfn2_macro_fused_nonprobempi.GLB_Z/dfn2_macro_fused_nonprobempi.LOC_Z == 2)]
dfn2MacFusnonProb_56mpi_1omp = dfn2_macro_fused_nonprobempi[(dfn2_macro_fused_nonprobempi.omp_thrd == 1) & (dfn2_macro_fused_nonprobempi.GLB_T/dfn2_macro_fused_nonprobempi.LOC_T == 7) & (dfn2_macro_fused_nonprobempi.GLB_X/dfn2_macro_fused_nonprobempi.LOC_X == 2) & (dfn2_macro_fused_nonprobempi.GLB_Y/dfn2_macro_fused_nonprobempi.LOC_Y == 2)& (dfn2_macro_fused_nonprobempi.GLB_Z/dfn2_macro_fused_nonprobempi.LOC_Z == 2)]
dfn2MacFusnonProb_64mpi_1omp = dfn2_macro_fused_nonprobempi[(dfn2_macro_fused_nonprobempi.omp_thrd == 1) & (dfn2_macro_fused_nonprobempi.GLB_T/dfn2_macro_fused_nonprobempi.LOC_T == 8) & (dfn2_macro_fused_nonprobempi.GLB_X/dfn2_macro_fused_nonprobempi.LOC_X == 2) & (dfn2_macro_fused_nonprobempi.GLB_Y/dfn2_macro_fused_nonprobempi.LOC_Y == 2)& (dfn2_macro_fused_nonprobempi.GLB_Z/dfn2_macro_fused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - macro fused: probempi vs nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.GFLOPS*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.GFLOPS*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.GFLOPS*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.GFLOPS*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.GFLOPS*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.GFLOPS*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.GFLOPS*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.GFLOPS*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro Fused: probempi vs nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend = dict(
                                x=1,
                                y=1,
                                title_font_family="Sitka Small",
                                bordercolor="Black",
                                borderwidth=2))
# Out:
# <div>                            <div id="2b9e5897-039f-4795-94c4-3a94f2c9ad00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b9e5897-039f-4795-94c4-3a94f2c9ad00")) {                    Plotly.newPlot(                        "2b9e5897-039f-4795-94c4-3a94f2c9ad00",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## BANDWIDTH - macro fused: probempi vs nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.BAND*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.BAND*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.BAND*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.BAND*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.BAND*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.BAND*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.BAND*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.BAND*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro Fused: probempi vs nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=2))
# Out:
# <div>                            <div id="2ea4ffb7-a1e2-4e9c-9d44-65a24a881c6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea4ffb7-a1e2-4e9c-9d44-65a24a881c6d")) {                    Plotly.newPlot(                        "2ea4ffb7-a1e2-4e9c-9d44-65a24a881c6d",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ### 3. macro_nonfused_probempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_nonfused_probempi["N_Nodes"] = 2
dfn2_macro_nonfused_probempi['NPX'] = (dfn2_macro_nonfused_probempi.GLB_X//dfn2_macro_nonfused_probempi.LOC_X)
dfn2_macro_nonfused_probempi['NPY'] = (dfn2_macro_nonfused_probempi.GLB_Y//dfn2_macro_nonfused_probempi.LOC_Y)
dfn2_macro_nonfused_probempi['NPZ'] = (dfn2_macro_nonfused_probempi.GLB_Z//dfn2_macro_nonfused_probempi.LOC_Z)
dfn2_macro_nonfused_probempi['NPT'] = (dfn2_macro_nonfused_probempi.GLB_T//dfn2_macro_nonfused_probempi.LOC_T)
dfn2_macro_nonfused_probempi["Total_proc"] = dfn2_macro_nonfused_probempi["omp_thrd"]* dfn2_macro_nonfused_probempi.MPI_size
# dfn2_macro_nonfused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_nonfused_probempi_summary = dfn2_macro_nonfused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_nonfused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacNonFusProb_16mpi_4omp = dfn2_macro_nonfused_probempi[(dfn2_macro_nonfused_probempi.omp_thrd == 4) & (dfn2_macro_nonfused_probempi.GLB_T/dfn2_macro_nonfused_probempi.LOC_T == 2) & (dfn2_macro_nonfused_probempi.GLB_X/dfn2_macro_nonfused_probempi.LOC_X == 2) & (dfn2_macro_nonfused_probempi.GLB_Y/dfn2_macro_nonfused_probempi.LOC_Y == 2)& (dfn2_macro_nonfused_probempi.GLB_Z/dfn2_macro_nonfused_probempi.LOC_Z == 2)]
dfn2MacNonFusProb_32mpi_2omp = dfn2_macro_nonfused_probempi[(dfn2_macro_nonfused_probempi.omp_thrd == 2) & (dfn2_macro_nonfused_probempi.GLB_T/dfn2_macro_nonfused_probempi.LOC_T == 4) & (dfn2_macro_nonfused_probempi.GLB_X/dfn2_macro_nonfused_probempi.LOC_X == 2) & (dfn2_macro_nonfused_probempi.GLB_Y/dfn2_macro_nonfused_probempi.LOC_Y == 2)& (dfn2_macro_nonfused_probempi.GLB_Z/dfn2_macro_nonfused_probempi.LOC_Z == 2)]
dfn2MacNonFusProb_56mpi_1omp = dfn2_macro_nonfused_probempi[(dfn2_macro_nonfused_probempi.omp_thrd == 1) & (dfn2_macro_nonfused_probempi.GLB_T/dfn2_macro_nonfused_probempi.LOC_T == 7) & (dfn2_macro_nonfused_probempi.GLB_X/dfn2_macro_nonfused_probempi.LOC_X == 2) & (dfn2_macro_nonfused_probempi.GLB_Y/dfn2_macro_nonfused_probempi.LOC_Y == 2)& (dfn2_macro_nonfused_probempi.GLB_Z/dfn2_macro_nonfused_probempi.LOC_Z == 2)]
dfn2MacNonFusProb_64mpi_1omp = dfn2_macro_nonfused_probempi[(dfn2_macro_nonfused_probempi.omp_thrd == 1) & (dfn2_macro_nonfused_probempi.GLB_T/dfn2_macro_nonfused_probempi.LOC_T == 8) & (dfn2_macro_nonfused_probempi.GLB_X/dfn2_macro_nonfused_probempi.LOC_X == 2) & (dfn2_macro_nonfused_probempi.GLB_Y/dfn2_macro_nonfused_probempi.LOC_Y == 2)& (dfn2_macro_nonfused_probempi.GLB_Z/dfn2_macro_nonfused_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 4. macro_nonfused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_nonfused_nonprobempi["N_Nodes"] = 2
dfn2_macro_nonfused_nonprobempi['NPX'] = (dfn2_macro_nonfused_nonprobempi.GLB_X//dfn2_macro_nonfused_nonprobempi.LOC_X)
dfn2_macro_nonfused_nonprobempi['NPY'] = (dfn2_macro_nonfused_nonprobempi.GLB_Y//dfn2_macro_nonfused_nonprobempi.LOC_Y)
dfn2_macro_nonfused_nonprobempi['NPZ'] = (dfn2_macro_nonfused_nonprobempi.GLB_Z//dfn2_macro_nonfused_nonprobempi.LOC_Z)
dfn2_macro_nonfused_nonprobempi['NPT'] = (dfn2_macro_nonfused_nonprobempi.GLB_T//dfn2_macro_nonfused_nonprobempi.LOC_T)
dfn2_macro_nonfused_nonprobempi["Total_proc"] = dfn2_macro_nonfused_nonprobempi["omp_thrd"]* dfn2_macro_nonfused_nonprobempi.MPI_size
# dfn2_macro_nonfused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_nonfused_nonprobempi_summary = dfn2_macro_nonfused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_nonfused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacNonFusNonProb_16mpi_4omp = dfn2_macro_nonfused_nonprobempi[(dfn2_macro_nonfused_nonprobempi.omp_thrd == 4) & (dfn2_macro_nonfused_nonprobempi.GLB_T/dfn2_macro_nonfused_nonprobempi.LOC_T == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_X/dfn2_macro_nonfused_nonprobempi.LOC_X == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_Y/dfn2_macro_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_macro_nonfused_nonprobempi.GLB_Z/dfn2_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfn2MacNonFusNonProb_32mpi_2omp = dfn2_macro_nonfused_nonprobempi[(dfn2_macro_nonfused_nonprobempi.omp_thrd == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_T/dfn2_macro_nonfused_nonprobempi.LOC_T == 4) & (dfn2_macro_nonfused_nonprobempi.GLB_X/dfn2_macro_nonfused_nonprobempi.LOC_X == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_Y/dfn2_macro_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_macro_nonfused_nonprobempi.GLB_Z/dfn2_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfn2MacNonFusNonProb_56mpi_1omp = dfn2_macro_nonfused_nonprobempi[(dfn2_macro_nonfused_nonprobempi.omp_thrd == 1) & (dfn2_macro_nonfused_nonprobempi.GLB_T/dfn2_macro_nonfused_nonprobempi.LOC_T == 7) & (dfn2_macro_nonfused_nonprobempi.GLB_X/dfn2_macro_nonfused_nonprobempi.LOC_X == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_Y/dfn2_macro_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_macro_nonfused_nonprobempi.GLB_Z/dfn2_macro_nonfused_nonprobempi.LOC_Z == 2)]
dfn2MacNonFusNonProb_64mpi_1omp = dfn2_macro_nonfused_nonprobempi[(dfn2_macro_nonfused_nonprobempi.omp_thrd == 1) & (dfn2_macro_nonfused_nonprobempi.GLB_T/dfn2_macro_nonfused_nonprobempi.LOC_T == 8) & (dfn2_macro_nonfused_nonprobempi.GLB_X/dfn2_macro_nonfused_nonprobempi.LOC_X == 2) & (dfn2_macro_nonfused_nonprobempi.GLB_Y/dfn2_macro_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_macro_nonfused_nonprobempi.GLB_Z/dfn2_macro_nonfused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - Macro nonfused: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_16mpi_4omp.GFLOPS*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_16mpi_4omp.GFLOPS*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_32mpi_2omp.GFLOPS*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_32mpi_2omp.GFLOPS*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_56mpi_1omp.GFLOPS*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_56mpi_1omp.GFLOPS*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_64mpi_1omp.GFLOPS*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_64mpi_1omp.GFLOPS*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro nonfused: Probempi vs Nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="ab4c0751-50f4-4f0d-aef6-3021f1e5b684" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab4c0751-50f4-4f0d-aef6-3021f1e5b684")) {                    Plotly.newPlot(                        "ab4c0751-50f4-4f0d-aef6-3021f1e5b684",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - Macro nonfused: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_16mpi_4omp.BAND*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_16mpi_4omp.BAND*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_32mpi_2omp.BAND*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_32mpi_2omp.BAND*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_56mpi_1omp.BAND*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_56mpi_1omp.BAND*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_64mpi_1omp.BAND*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_64mpi_1omp.BAND*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro nonfused: Probempi vs Nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="2495ec6e-cee9-4727-aea8-a943f82f1825" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2495ec6e-cee9-4727-aea8-a943f82f1825")) {                    Plotly.newPlot(                        "2495ec6e-cee9-4727-aea8-a943f82f1825",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ### 5. macro_newgeo_probempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_newgeo_probempi["N_Nodes"] = 2
dfn2_macro_newgeo_probempi['NPX'] = (dfn2_macro_newgeo_probempi.GLB_X//dfn2_macro_newgeo_probempi.LOC_X)
dfn2_macro_newgeo_probempi['NPY'] = (dfn2_macro_newgeo_probempi.GLB_Y//dfn2_macro_newgeo_probempi.LOC_Y)
dfn2_macro_newgeo_probempi['NPZ'] = (dfn2_macro_newgeo_probempi.GLB_Z//dfn2_macro_newgeo_probempi.LOC_Z)
dfn2_macro_newgeo_probempi['NPT'] = (dfn2_macro_newgeo_probempi.GLB_T//dfn2_macro_newgeo_probempi.LOC_T)
dfn2_macro_newgeo_probempi["Total_proc"] = dfn2_macro_newgeo_probempi["omp_thrd"]* dfn2_macro_newgeo_probempi.MPI_size
# dfn2_macro_newgeo_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_newgeo_probempi_summary =dfn2_macro_newgeo_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_newgeo_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacNewgeoProb_16mpi_4omp = dfn2_macro_newgeo_probempi[(dfn2_macro_newgeo_probempi.omp_thrd == 4) & (dfn2_macro_newgeo_probempi.GLB_T/dfn2_macro_newgeo_probempi.LOC_T == 2) & (dfn2_macro_newgeo_probempi.GLB_X/dfn2_macro_newgeo_probempi.LOC_X == 2) & (dfn2_macro_newgeo_probempi.GLB_Y/dfn2_macro_newgeo_probempi.LOC_Y == 2)& (dfn2_macro_newgeo_probempi.GLB_Z/dfn2_macro_newgeo_probempi.LOC_Z == 2)]
dfn2MacNewgeoProb_32mpi_2omp = dfn2_macro_newgeo_probempi[(dfn2_macro_newgeo_probempi.omp_thrd == 2) & (dfn2_macro_newgeo_probempi.GLB_T/dfn2_macro_newgeo_probempi.LOC_T == 4) & (dfn2_macro_newgeo_probempi.GLB_X/dfn2_macro_newgeo_probempi.LOC_X == 2) & (dfn2_macro_newgeo_probempi.GLB_Y/dfn2_macro_newgeo_probempi.LOC_Y == 2)& (dfn2_macro_newgeo_probempi.GLB_Z/dfn2_macro_newgeo_probempi.LOC_Z == 2)]
dfn2MacNewgeoProb_56mpi_1omp = dfn2_macro_newgeo_probempi[(dfn2_macro_newgeo_probempi.omp_thrd == 1) & (dfn2_macro_newgeo_probempi.GLB_T/dfn2_macro_newgeo_probempi.LOC_T == 7) & (dfn2_macro_newgeo_probempi.GLB_X/dfn2_macro_newgeo_probempi.LOC_X == 2) & (dfn2_macro_newgeo_probempi.GLB_Y/dfn2_macro_newgeo_probempi.LOC_Y == 2)& (dfn2_macro_newgeo_probempi.GLB_Z/dfn2_macro_newgeo_probempi.LOC_Z == 2)]
dfn2MacNewgeoProb_64mpi_1omp = dfn2_macro_newgeo_probempi[(dfn2_macro_newgeo_probempi.omp_thrd == 1) & (dfn2_macro_newgeo_probempi.GLB_T/dfn2_macro_newgeo_probempi.LOC_T == 8) & (dfn2_macro_newgeo_probempi.GLB_X/dfn2_macro_newgeo_probempi.LOC_X == 2) & (dfn2_macro_newgeo_probempi.GLB_Y/dfn2_macro_newgeo_probempi.LOC_Y == 2)& (dfn2_macro_newgeo_probempi.GLB_Z/dfn2_macro_newgeo_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 6. macro_newgeo_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_macro_newgeo_nonprobempi["N_Nodes"] = 2
dfn2_macro_newgeo_nonprobempi['NPX'] = (dfn2_macro_newgeo_nonprobempi.GLB_X//dfn2_macro_newgeo_nonprobempi.LOC_X)
dfn2_macro_newgeo_nonprobempi['NPY'] = (dfn2_macro_newgeo_nonprobempi.GLB_Y//dfn2_macro_newgeo_nonprobempi.LOC_Y)
dfn2_macro_newgeo_nonprobempi['NPZ'] = (dfn2_macro_newgeo_nonprobempi.GLB_Z//dfn2_macro_newgeo_nonprobempi.LOC_Z)
dfn2_macro_newgeo_nonprobempi['NPT'] = (dfn2_macro_newgeo_nonprobempi.GLB_T//dfn2_macro_newgeo_nonprobempi.LOC_T)
dfn2_macro_newgeo_nonprobempi["Total_proc"] = dfn2_macro_newgeo_nonprobempi["omp_thrd"]* dfn2_macro_newgeo_nonprobempi.MPI_size
# dfn2_macro_newgeo_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_macro_newgeo_nonprobempi_summary = dfn2_macro_newgeo_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_macro_newgeo_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2MacNewgeoNonProb_16mpi_4omp = dfn2_macro_newgeo_nonprobempi[(dfn2_macro_newgeo_nonprobempi.omp_thrd == 4) & (dfn2_macro_newgeo_nonprobempi.GLB_T/dfn2_macro_newgeo_nonprobempi.LOC_T == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_X/dfn2_macro_newgeo_nonprobempi.LOC_X == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_Y/dfn2_macro_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_macro_newgeo_nonprobempi.GLB_Z/dfn2_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfn2MacNewgeoNonProb_32mpi_2omp = dfn2_macro_newgeo_nonprobempi[(dfn2_macro_newgeo_nonprobempi.omp_thrd == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_T/dfn2_macro_newgeo_nonprobempi.LOC_T == 4) & (dfn2_macro_newgeo_nonprobempi.GLB_X/dfn2_macro_newgeo_nonprobempi.LOC_X == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_Y/dfn2_macro_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_macro_newgeo_nonprobempi.GLB_Z/dfn2_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfn2MacNewgeoNonProb_56mpi_1omp = dfn2_macro_newgeo_nonprobempi[(dfn2_macro_newgeo_nonprobempi.omp_thrd == 1) & (dfn2_macro_newgeo_nonprobempi.GLB_T/dfn2_macro_newgeo_nonprobempi.LOC_T == 7) & (dfn2_macro_newgeo_nonprobempi.GLB_X/dfn2_macro_newgeo_nonprobempi.LOC_X == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_Y/dfn2_macro_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_macro_newgeo_nonprobempi.GLB_Z/dfn2_macro_newgeo_nonprobempi.LOC_Z == 2)]
dfn2MacNewgeoNonProb_64mpi_1omp = dfn2_macro_newgeo_nonprobempi[(dfn2_macro_newgeo_nonprobempi.omp_thrd == 1) & (dfn2_macro_newgeo_nonprobempi.GLB_T/dfn2_macro_newgeo_nonprobempi.LOC_T == 8) & (dfn2_macro_newgeo_nonprobempi.GLB_X/dfn2_macro_newgeo_nonprobempi.LOC_X == 2) & (dfn2_macro_newgeo_nonprobempi.GLB_Y/dfn2_macro_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_macro_newgeo_nonprobempi.GLB_Z/dfn2_macro_newgeo_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - Macro Newgeometry: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_16mpi_4omp.GFLOPS*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_16mpi_4omp.GFLOPS*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_32mpi_2omp.GFLOPS*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_32mpi_2omp.GFLOPS*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_56mpi_1omp.GFLOPS*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_56mpi_1omp.GFLOPS*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_64mpi_1omp.GFLOPS*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_64mpi_1omp.GFLOPS*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                          line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"Macro Newgeometry: Probempi vs Nonprobempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="dbfedc53-d573-4695-8dca-8c0e61fe139f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbfedc53-d573-4695-8dca-8c0e61fe139f")) {                    Plotly.newPlot(                        "dbfedc53-d573-4695-8dca-8c0e61fe139f",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - Macro Newgeometry: Probempi vs Nonprobempi

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_16mpi_4omp.BAND*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_16mpi_4omp.BAND*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_32mpi_2omp.BAND*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_32mpi_2omp.BAND*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_56mpi_1omp.BAND*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_56mpi_1omp.BAND*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_64mpi_1omp.BAND*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_64mpi_1omp.BAND*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"Macro Newgeometry: Probempi vs Nonprobempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="a218f3e6-c4c0-4c2d-88e7-66cea8a6f465" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a218f3e6-c4c0-4c2d-88e7-66cea8a6f465")) {                    Plotly.newPlot(                        "a218f3e6-c4c0-4c2d-88e7-66cea8a6f465",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # AVX CASES

# %% [markdown]
# ### 1. avx_fused_probmpi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_fused_probmpi["N_Nodes"] = 2
dfn2_avx_fused_probmpi['NPX'] = (dfn2_avx_fused_probmpi.GLB_X//dfn2_avx_fused_probmpi.LOC_X)
dfn2_avx_fused_probmpi['NPY'] = (dfn2_avx_fused_probmpi.GLB_Y//dfn2_avx_fused_probmpi.LOC_Y)
dfn2_avx_fused_probmpi['NPZ'] = (dfn2_avx_fused_probmpi.GLB_Z//dfn2_avx_fused_probmpi.LOC_Z)
dfn2_avx_fused_probmpi['NPT'] = (dfn2_avx_fused_probmpi.GLB_T//dfn2_avx_fused_probmpi.LOC_T)
dfn2_avx_fused_probmpi["Total_proc"] = dfn2_avx_fused_probmpi["omp_thrd"]* dfn2_avx_fused_probmpi.MPI_size
# dfn2_avx_fused_probmpi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_fused_probmpi_summary = dfn2_avx_fused_probmpi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_fused_probmpi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxFusProb_16mpi_4omp = dfn2_avx_fused_probmpi[(dfn2_avx_fused_probmpi.omp_thrd == 4) & (dfn2_avx_fused_probmpi.GLB_T/dfn2_avx_fused_probmpi.LOC_T == 2) & (dfn2_avx_fused_probmpi.GLB_X/dfn2_avx_fused_probmpi.LOC_X == 2) & (dfn2_avx_fused_probmpi.GLB_Y/dfn2_avx_fused_probmpi.LOC_Y == 2)& (dfn2_avx_fused_probmpi.GLB_Z/dfn2_avx_fused_probmpi.LOC_Z == 2)]
dfn2AvxFusProb_32mpi_2omp = dfn2_avx_fused_probmpi[(dfn2_avx_fused_probmpi.omp_thrd == 2) & (dfn2_avx_fused_probmpi.GLB_T/dfn2_avx_fused_probmpi.LOC_T == 4) & (dfn2_avx_fused_probmpi.GLB_X/dfn2_avx_fused_probmpi.LOC_X == 2) & (dfn2_avx_fused_probmpi.GLB_Y/dfn2_avx_fused_probmpi.LOC_Y == 2)& (dfn2_avx_fused_probmpi.GLB_Z/dfn2_avx_fused_probmpi.LOC_Z == 2)]
dfn2AvxFusProb_56mpi_1omp = dfn2_avx_fused_probmpi[(dfn2_avx_fused_probmpi.omp_thrd == 1) & (dfn2_avx_fused_probmpi.GLB_T/dfn2_avx_fused_probmpi.LOC_T == 7) & (dfn2_avx_fused_probmpi.GLB_X/dfn2_avx_fused_probmpi.LOC_X == 2) & (dfn2_avx_fused_probmpi.GLB_Y/dfn2_avx_fused_probmpi.LOC_Y == 2)& (dfn2_avx_fused_probmpi.GLB_Z/dfn2_avx_fused_probmpi.LOC_Z == 2)]
dfn2AvxFusProb_64mpi_1omp = dfn2_avx_fused_probmpi[(dfn2_avx_fused_probmpi.omp_thrd == 1) & (dfn2_avx_fused_probmpi.GLB_T/dfn2_avx_fused_probmpi.LOC_T == 8) & (dfn2_avx_fused_probmpi.GLB_X/dfn2_avx_fused_probmpi.LOC_X == 2) & (dfn2_avx_fused_probmpi.GLB_Y/dfn2_avx_fused_probmpi.LOC_Y == 2)& (dfn2_avx_fused_probmpi.GLB_Z/dfn2_avx_fused_probmpi.LOC_Z == 2)]

# %% [markdown]
# ### 2. avx_fused_nonprobmpi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_fused_nonprobmpi["N_Nodes"] = 2
dfn2_avx_fused_nonprobmpi['NPX'] = (dfn2_avx_fused_nonprobmpi.GLB_X//dfn2_avx_fused_nonprobmpi.LOC_X)
dfn2_avx_fused_nonprobmpi['NPY'] = (dfn2_avx_fused_nonprobmpi.GLB_Y//dfn2_avx_fused_nonprobmpi.LOC_Y)
dfn2_avx_fused_nonprobmpi['NPZ'] = (dfn2_avx_fused_nonprobmpi.GLB_Z//dfn2_avx_fused_nonprobmpi.LOC_Z)
dfn2_avx_fused_nonprobmpi['NPT'] = (dfn2_avx_fused_nonprobmpi.GLB_T//dfn2_avx_fused_nonprobmpi.LOC_T)
dfn2_avx_fused_nonprobmpi["Total_proc"] = dfn2_avx_fused_nonprobmpi["omp_thrd"]* dfn2_avx_fused_nonprobmpi.MPI_size
# dfn2_avx_fused_nonprobmpi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_fused_nonprobmpi_summary = dfn2_avx_fused_nonprobmpi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_fused_nonprobmpi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxFusNonProb_16mpi_4omp = dfn2_avx_fused_nonprobmpi[(dfn2_avx_fused_nonprobmpi.omp_thrd == 4) & (dfn2_avx_fused_nonprobmpi.GLB_T/dfn2_avx_fused_nonprobmpi.LOC_T == 2) & (dfn2_avx_fused_nonprobmpi.GLB_X/dfn2_avx_fused_nonprobmpi.LOC_X == 2) & (dfn2_avx_fused_nonprobmpi.GLB_Y/dfn2_avx_fused_nonprobmpi.LOC_Y == 2)& (dfn2_avx_fused_nonprobmpi.GLB_Z/dfn2_avx_fused_nonprobmpi.LOC_Z == 2)]
dfn2AvxFusNonProb_32mpi_2omp = dfn2_avx_fused_nonprobmpi[(dfn2_avx_fused_nonprobmpi.omp_thrd == 2) & (dfn2_avx_fused_nonprobmpi.GLB_T/dfn2_avx_fused_nonprobmpi.LOC_T == 4) & (dfn2_avx_fused_nonprobmpi.GLB_X/dfn2_avx_fused_nonprobmpi.LOC_X == 2) & (dfn2_avx_fused_nonprobmpi.GLB_Y/dfn2_avx_fused_nonprobmpi.LOC_Y == 2)& (dfn2_avx_fused_nonprobmpi.GLB_Z/dfn2_avx_fused_nonprobmpi.LOC_Z == 2)]
dfn2AvxFusNonProb_56mpi_1omp = dfn2_avx_fused_nonprobmpi[(dfn2_avx_fused_nonprobmpi.omp_thrd == 1) & (dfn2_avx_fused_nonprobmpi.GLB_T/dfn2_avx_fused_nonprobmpi.LOC_T == 7) & (dfn2_avx_fused_nonprobmpi.GLB_X/dfn2_avx_fused_nonprobmpi.LOC_X == 2) & (dfn2_avx_fused_nonprobmpi.GLB_Y/dfn2_avx_fused_nonprobmpi.LOC_Y == 2)& (dfn2_avx_fused_nonprobmpi.GLB_Z/dfn2_avx_fused_nonprobmpi.LOC_Z == 2)]
dfn2AvxFusNonProb_64mpi_1omp = dfn2_avx_fused_nonprobmpi[(dfn2_avx_fused_nonprobmpi.omp_thrd == 1) & (dfn2_avx_fused_nonprobmpi.GLB_T/dfn2_avx_fused_nonprobmpi.LOC_T == 8) & (dfn2_avx_fused_nonprobmpi.GLB_X/dfn2_avx_fused_nonprobmpi.LOC_X == 2) & (dfn2_avx_fused_nonprobmpi.GLB_Y/dfn2_avx_fused_nonprobmpi.LOC_Y == 2)& (dfn2_avx_fused_nonprobmpi.GLB_Z/dfn2_avx_fused_nonprobmpi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-Fused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_16mpi_4omp.GFLOPS*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_16mpi_4omp.GFLOPS*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_32mpi_2omp.GFLOPS*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_32mpi_2omp.GFLOPS*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_56mpi_1omp.GFLOPS*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_56mpi_1omp.GFLOPS*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_64mpi_1omp.GFLOPS*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_64mpi_1omp.GFLOPS*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-Fused: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="eb9df053-fb38-4367-bfa1-adbf78a8e3d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb9df053-fb38-4367-bfa1-adbf78a8e3d0")) {                    Plotly.newPlot(                        "eb9df053-fb38-4367-bfa1-adbf78a8e3d0",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.0
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-Fused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_16mpi_4omp.BAND*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_16mpi_4omp.BAND*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_32mpi_2omp.BAND*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_32mpi_2omp.BAND*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_56mpi_1omp.BAND*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_56mpi_1omp.BAND*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_64mpi_1omp.BAND*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_64mpi_1omp.BAND*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-Fused: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="98059da3-f0f3-41b6-890c-8a079db161eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98059da3-f0f3-41b6-890c-8a079db161eb")) {                    Plotly.newPlot(                        "98059da3-f0f3-41b6-890c-8a079db161eb",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.0
# ...

# %% [markdown]
# ### 3. avx_nonfused_probempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_nonfused_probempi["N_Nodes"] = 2
dfn2_avx_nonfused_probempi['NPX'] = (dfn2_avx_nonfused_probempi.GLB_X//dfn2_avx_nonfused_probempi.LOC_X)
dfn2_avx_nonfused_probempi['NPY'] = (dfn2_avx_nonfused_probempi.GLB_Y//dfn2_avx_nonfused_probempi.LOC_Y)
dfn2_avx_nonfused_probempi['NPZ'] = (dfn2_avx_nonfused_probempi.GLB_Z//dfn2_avx_nonfused_probempi.LOC_Z)
dfn2_avx_nonfused_probempi['NPT'] = (dfn2_avx_nonfused_probempi.GLB_T//dfn2_avx_nonfused_probempi.LOC_T)
dfn2_avx_nonfused_probempi["Total_proc"] = dfn2_avx_nonfused_probempi["omp_thrd"]* dfn2_avx_nonfused_probempi.MPI_size
# dfn2_avx_nonfused_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_nonfused_probempi_summary = dfn2_avx_nonfused_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_nonfused_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxNonFusProb_16mpi_4omp = dfn2_avx_nonfused_probempi[(dfn2_avx_nonfused_probempi.omp_thrd == 4) & (dfn2_avx_nonfused_probempi.GLB_T/dfn2_avx_nonfused_probempi.LOC_T == 2) & (dfn2_avx_nonfused_probempi.GLB_X/dfn2_avx_nonfused_probempi.LOC_X == 2) & (dfn2_avx_nonfused_probempi.GLB_Y/dfn2_avx_nonfused_probempi.LOC_Y == 2)& (dfn2_avx_nonfused_probempi.GLB_Z/dfn2_avx_nonfused_probempi.LOC_Z == 2)]
dfn2AvxNonFusProb_32mpi_2omp = dfn2_avx_nonfused_probempi[(dfn2_avx_nonfused_probempi.omp_thrd == 2) & (dfn2_avx_nonfused_probempi.GLB_T/dfn2_avx_nonfused_probempi.LOC_T == 4) & (dfn2_avx_nonfused_probempi.GLB_X/dfn2_avx_nonfused_probempi.LOC_X == 2) & (dfn2_avx_nonfused_probempi.GLB_Y/dfn2_avx_nonfused_probempi.LOC_Y == 2)& (dfn2_avx_nonfused_probempi.GLB_Z/dfn2_avx_nonfused_probempi.LOC_Z == 2)]
dfn2AvxNonFusProb_56mpi_1omp = dfn2_avx_nonfused_probempi[(dfn2_avx_nonfused_probempi.omp_thrd == 1) & (dfn2_avx_nonfused_probempi.GLB_T/dfn2_avx_nonfused_probempi.LOC_T == 7) & (dfn2_avx_nonfused_probempi.GLB_X/dfn2_avx_nonfused_probempi.LOC_X == 2) & (dfn2_avx_nonfused_probempi.GLB_Y/dfn2_avx_nonfused_probempi.LOC_Y == 2)& (dfn2_avx_nonfused_probempi.GLB_Z/dfn2_avx_nonfused_probempi.LOC_Z == 2)]
dfn2AvxNonFusProb_64mpi_1omp = dfn2_avx_nonfused_probempi[(dfn2_avx_nonfused_probempi.omp_thrd == 1) & (dfn2_avx_nonfused_probempi.GLB_T/dfn2_avx_nonfused_probempi.LOC_T == 8) & (dfn2_avx_nonfused_probempi.GLB_X/dfn2_avx_nonfused_probempi.LOC_X == 2) & (dfn2_avx_nonfused_probempi.GLB_Y/dfn2_avx_nonfused_probempi.LOC_Y == 2)& (dfn2_avx_nonfused_probempi.GLB_Z/dfn2_avx_nonfused_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 4. avx_nonfused_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_nonfused_nonprobempi["N_Nodes"] = 2
dfn2_avx_nonfused_nonprobempi['NPX'] = (dfn2_avx_nonfused_nonprobempi.GLB_X//dfn2_avx_nonfused_nonprobempi.LOC_X)
dfn2_avx_nonfused_nonprobempi['NPY'] = (dfn2_avx_nonfused_nonprobempi.GLB_Y//dfn2_avx_nonfused_nonprobempi.LOC_Y)
dfn2_avx_nonfused_nonprobempi['NPZ'] = (dfn2_avx_nonfused_nonprobempi.GLB_Z//dfn2_avx_nonfused_nonprobempi.LOC_Z)
dfn2_avx_nonfused_nonprobempi['NPT'] = (dfn2_avx_nonfused_nonprobempi.GLB_T//dfn2_avx_nonfused_nonprobempi.LOC_T)
dfn2_avx_nonfused_nonprobempi["Total_proc"] = dfn2_avx_nonfused_nonprobempi["omp_thrd"]* dfn2_avx_nonfused_nonprobempi.MPI_size
# dfn2_avx_nonfused_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_nonfused_nonprobempi_summary = dfn2_avx_nonfused_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_nonfused_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxNonFusNonProb_16mpi_4omp = dfn2_avx_nonfused_nonprobempi[(dfn2_avx_nonfused_nonprobempi.omp_thrd == 4) & (dfn2_avx_nonfused_nonprobempi.GLB_T/dfn2_avx_nonfused_nonprobempi.LOC_T == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_X/dfn2_avx_nonfused_nonprobempi.LOC_X == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_Y/dfn2_avx_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_avx_nonfused_nonprobempi.GLB_Z/dfn2_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfn2AvxNonFusNonProb_32mpi_2omp = dfn2_avx_nonfused_nonprobempi[(dfn2_avx_nonfused_nonprobempi.omp_thrd == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_T/dfn2_avx_nonfused_nonprobempi.LOC_T == 4) & (dfn2_avx_nonfused_nonprobempi.GLB_X/dfn2_avx_nonfused_nonprobempi.LOC_X == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_Y/dfn2_avx_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_avx_nonfused_nonprobempi.GLB_Z/dfn2_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfn2AvxNonFusNonProb_56mpi_1omp = dfn2_avx_nonfused_nonprobempi[(dfn2_avx_nonfused_nonprobempi.omp_thrd == 1) & (dfn2_avx_nonfused_nonprobempi.GLB_T/dfn2_avx_nonfused_nonprobempi.LOC_T == 7) & (dfn2_avx_nonfused_nonprobempi.GLB_X/dfn2_avx_nonfused_nonprobempi.LOC_X == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_Y/dfn2_avx_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_avx_nonfused_nonprobempi.GLB_Z/dfn2_avx_nonfused_nonprobempi.LOC_Z == 2)]
dfn2AvxNonFusNonProb_64mpi_1omp = dfn2_avx_nonfused_nonprobempi[(dfn2_avx_nonfused_nonprobempi.omp_thrd == 1) & (dfn2_avx_nonfused_nonprobempi.GLB_T/dfn2_avx_nonfused_nonprobempi.LOC_T == 8) & (dfn2_avx_nonfused_nonprobempi.GLB_X/dfn2_avx_nonfused_nonprobempi.LOC_X == 2) & (dfn2_avx_nonfused_nonprobempi.GLB_Y/dfn2_avx_nonfused_nonprobempi.LOC_Y == 2)& (dfn2_avx_nonfused_nonprobempi.GLB_Z/dfn2_avx_nonfused_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-NonFused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_16mpi_4omp.GFLOPS*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_16mpi_4omp.GFLOPS*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_32mpi_2omp.GFLOPS*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_32mpi_2omp.GFLOPS*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_56mpi_1omp.GFLOPS*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_56mpi_1omp.GFLOPS*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_64mpi_1omp.GFLOPS*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_64mpi_1omp.GFLOPS*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))




# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-NonFused: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="d30807e8-ada3-4e0e-9887-073f358844c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d30807e8-ada3-4e0e-9887-073f358844c5")) {                    Plotly.newPlot(                        "d30807e8-ada3-4e0e-9887-073f358844c5",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-NonFused: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_16mpi_4omp.BAND*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_16mpi_4omp.BAND*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_32mpi_2omp.BAND*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_32mpi_2omp.BAND*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_56mpi_1omp.BAND*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_56mpi_1omp.BAND*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_64mpi_1omp.BAND*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_64mpi_1omp.BAND*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-NonFused: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="eefb454d-dae3-4b06-b8d5-09f2b426327d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eefb454d-dae3-4b06-b8d5-09f2b426327d")) {                    Plotly.newPlot(                        "eefb454d-dae3-4b06-b8d5-09f2b426327d",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ### 5. avx_newgeo_probempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_newgeo_probempi["N_Nodes"] = 2
dfn2_avx_newgeo_probempi['NPX'] = (dfn2_avx_newgeo_probempi.GLB_X//dfn2_avx_newgeo_probempi.LOC_X)
dfn2_avx_newgeo_probempi['NPY'] = (dfn2_avx_newgeo_probempi.GLB_Y//dfn2_avx_newgeo_probempi.LOC_Y)
dfn2_avx_newgeo_probempi['NPZ'] = (dfn2_avx_newgeo_probempi.GLB_Z//dfn2_avx_newgeo_probempi.LOC_Z)
dfn2_avx_newgeo_probempi['NPT'] = (dfn2_avx_newgeo_probempi.GLB_T//dfn2_avx_newgeo_probempi.LOC_T)
dfn2_avx_newgeo_probempi["Total_proc"] = dfn2_avx_newgeo_probempi["omp_thrd"]* dfn2_avx_newgeo_probempi.MPI_size
# dfn2_avx_newgeo_probempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_newgeo_probempi_summary = dfn2_avx_newgeo_probempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_newgeo_probempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxNewgeoProb_16mpi_4omp = dfn2_avx_newgeo_probempi[(dfn2_avx_newgeo_probempi.omp_thrd == 4) & (dfn2_avx_newgeo_probempi.GLB_T/dfn2_avx_newgeo_probempi.LOC_T == 2) & (dfn2_avx_newgeo_probempi.GLB_X/dfn2_avx_newgeo_probempi.LOC_X == 2) & (dfn2_avx_newgeo_probempi.GLB_Y/dfn2_avx_newgeo_probempi.LOC_Y == 2)& (dfn2_avx_newgeo_probempi.GLB_Z/dfn2_avx_newgeo_probempi.LOC_Z == 2)]
dfn2AvxNewgeoProb_32mpi_2omp = dfn2_avx_newgeo_probempi[(dfn2_avx_newgeo_probempi.omp_thrd == 2) & (dfn2_avx_newgeo_probempi.GLB_T/dfn2_avx_newgeo_probempi.LOC_T == 4) & (dfn2_avx_newgeo_probempi.GLB_X/dfn2_avx_newgeo_probempi.LOC_X == 2) & (dfn2_avx_newgeo_probempi.GLB_Y/dfn2_avx_newgeo_probempi.LOC_Y == 2)& (dfn2_avx_newgeo_probempi.GLB_Z/dfn2_avx_newgeo_probempi.LOC_Z == 2)]
dfn2AvxNewgeoProb_56mpi_1omp = dfn2_avx_newgeo_probempi[(dfn2_avx_newgeo_probempi.omp_thrd == 1) & (dfn2_avx_newgeo_probempi.GLB_T/dfn2_avx_newgeo_probempi.LOC_T == 7) & (dfn2_avx_newgeo_probempi.GLB_X/dfn2_avx_newgeo_probempi.LOC_X == 2) & (dfn2_avx_newgeo_probempi.GLB_Y/dfn2_avx_newgeo_probempi.LOC_Y == 2)& (dfn2_avx_newgeo_probempi.GLB_Z/dfn2_avx_newgeo_probempi.LOC_Z == 2)]
dfn2AvxNewgeoProb_64mpi_1omp = dfn2_avx_newgeo_probempi[(dfn2_avx_newgeo_probempi.omp_thrd == 1) & (dfn2_avx_newgeo_probempi.GLB_T/dfn2_avx_newgeo_probempi.LOC_T == 8) & (dfn2_avx_newgeo_probempi.GLB_X/dfn2_avx_newgeo_probempi.LOC_X == 2) & (dfn2_avx_newgeo_probempi.GLB_Y/dfn2_avx_newgeo_probempi.LOC_Y == 2)& (dfn2_avx_newgeo_probempi.GLB_Z/dfn2_avx_newgeo_probempi.LOC_Z == 2)]

# %% [markdown]
# ### 6. avx_newgeo_nonprobempi

# %% [markdown]
# ### Add Columns

# %%
dfn2_avx_newgeo_nonprobempi["N_Nodes"] = 2
dfn2_avx_newgeo_nonprobempi['NPX'] = (dfn2_avx_newgeo_nonprobempi.GLB_X//dfn2_avx_newgeo_nonprobempi.LOC_X)
dfn2_avx_newgeo_nonprobempi['NPY'] = (dfn2_avx_newgeo_nonprobempi.GLB_Y//dfn2_avx_newgeo_nonprobempi.LOC_Y)
dfn2_avx_newgeo_nonprobempi['NPZ'] = (dfn2_avx_newgeo_nonprobempi.GLB_Z//dfn2_avx_newgeo_nonprobempi.LOC_Z)
dfn2_avx_newgeo_nonprobempi['NPT'] = (dfn2_avx_newgeo_nonprobempi.GLB_T//dfn2_avx_newgeo_nonprobempi.LOC_T)
dfn2_avx_newgeo_nonprobempi["Total_proc"] = dfn2_avx_newgeo_nonprobempi["omp_thrd"]* dfn2_avx_newgeo_nonprobempi.MPI_size
# dfn2_avx_newgeo_nonprobempi.columns

# %% [markdown]
# ### Data Summary

# %%
dfn2_avx_newgeo_nonprobempi_summary = dfn2_avx_newgeo_nonprobempi.groupby(['MPI_size','omp_thrd','NPT','NPX', 'NPY', 'NPZ',"Total_proc"]).size().reset_index(name = 'size')
dfn2_avx_newgeo_nonprobempi_summary
# Out:
#    MPI_size  omp_thrd  NPT  NPX  NPY  NPZ  Total_proc  size
# 0        16         4    2    2    2    2          64    29
# 1        32         2    4    2    2    2          64    13
# 2        56         1    7    2    2    2          56     3
# 3        64         1    8    2    2    2          64     5

# %% [markdown]
# ### Cases Set up

# %%
dfn2AvxNewgeoNonProb_16mpi_4omp = dfn2_avx_newgeo_nonprobempi[(dfn2_avx_newgeo_nonprobempi.omp_thrd == 4) & (dfn2_avx_newgeo_nonprobempi.GLB_T/dfn2_avx_newgeo_nonprobempi.LOC_T == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_X/dfn2_avx_newgeo_nonprobempi.LOC_X == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_Y/dfn2_avx_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_avx_newgeo_nonprobempi.GLB_Z/dfn2_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfn2AvxNewgeoNonProb_32mpi_2omp = dfn2_avx_newgeo_nonprobempi[(dfn2_avx_newgeo_nonprobempi.omp_thrd == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_T/dfn2_avx_newgeo_nonprobempi.LOC_T == 4) & (dfn2_avx_newgeo_nonprobempi.GLB_X/dfn2_avx_newgeo_nonprobempi.LOC_X == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_Y/dfn2_avx_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_avx_newgeo_nonprobempi.GLB_Z/dfn2_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfn2AvxNewgeoNonProb_56mpi_1omp = dfn2_avx_newgeo_nonprobempi[(dfn2_avx_newgeo_nonprobempi.omp_thrd == 1) & (dfn2_avx_newgeo_nonprobempi.GLB_T/dfn2_avx_newgeo_nonprobempi.LOC_T == 7) & (dfn2_avx_newgeo_nonprobempi.GLB_X/dfn2_avx_newgeo_nonprobempi.LOC_X == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_Y/dfn2_avx_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_avx_newgeo_nonprobempi.GLB_Z/dfn2_avx_newgeo_nonprobempi.LOC_Z == 2)]
dfn2AvxNewgeoNonProb_64mpi_1omp = dfn2_avx_newgeo_nonprobempi[(dfn2_avx_newgeo_nonprobempi.omp_thrd == 1) & (dfn2_avx_newgeo_nonprobempi.GLB_T/dfn2_avx_newgeo_nonprobempi.LOC_T == 8) & (dfn2_avx_newgeo_nonprobempi.GLB_X/dfn2_avx_newgeo_nonprobempi.LOC_X == 2) & (dfn2_avx_newgeo_nonprobempi.GLB_Y/dfn2_avx_newgeo_nonprobempi.LOC_Y == 2)& (dfn2_avx_newgeo_nonprobempi.GLB_Z/dfn2_avx_newgeo_nonprobempi.LOC_Z == 2)]

# %% [markdown]
# ## GFLOPS - AVX-Newgeo: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_16mpi_4omp.GFLOPS*(dfn2AvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_16mpi_4omp.GFLOPS*(dfn2AvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_8mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_32mpi_2omp.GFLOPS*(dfn2AvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_32mpi_2omp.GFLOPS*(dfn2AvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_56mpi_1omp.GFLOPS*(dfn2AvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_56mpi_1omp.GFLOPS*(dfn2AvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_64mpi_1omp.GFLOPS*(dfn2AvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_64mpi_1omp.GFLOPS*(dfn2AvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"AVX-Newgeo: Probmpi vs Non-Probempi" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="f2f10647-9fd3-4ca3-8709-17667fb7f631" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2f10647-9fd3-4ca3-8709-17667fb7f631")) {                    Plotly.newPlot(                        "f2f10647-9fd3-4ca3-8709-17667fb7f631",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## BANDWIDTH - AVX-Newgeo: Probmpi vs Non-Probempi

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_16mpi_4omp.BAND*(dfn2AvxNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_16mpi_4omp.BAND*(dfn2AvxNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_32mpi_2omp.BAND*(dfn2AvxNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_32mpi_2omp.BAND*(dfn2AvxNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_56mpi_1omp.BAND*(dfn2AvxNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_56mpi_1omp.BAND*(dfn2AvxNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoProb_64mpi_1omp.BAND*(dfn2AvxNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNewgeoNonProb_64mpi_1omp.BAND*(dfn2AvxNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNewgeoNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"AVX-Newgeo: Probmpi vs Non-Probempi" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="978c5931-bc47-428b-83e5-3bb27f30b39c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("978c5931-bc47-428b-83e5-3bb27f30b39c")) {                    Plotly.newPlot(                        "978c5931-bc47-428b-83e5-3bb27f30b39c",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"AvxNewgeoProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # Comparisons

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.GFLOPS*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_16mpi_4omp.GFLOPS*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.GFLOPS*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_32mpi_2omp.GFLOPS*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.GFLOPS*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_56mpi_1omp.GFLOPS*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.GFLOPS*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_64mpi_1omp.GFLOPS*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))




# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="d33c2302-b055-4489-a982-a207787f5187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d33c2302-b055-4489-a982-a207787f5187")) {                    Plotly.newPlot(                        "d33c2302-b055-4489-a982-a207787f5187",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (Probempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.BAND*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_16mpi_4omp.BAND*(dfn2AvxFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.BAND*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_32mpi_2omp.BAND*(dfn2AvxFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.BAND*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_56mpi_1omp.BAND*(dfn2AvxFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.BAND*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusProb_64mpi_1omp.BAND*(dfn2AvxFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)


fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Probempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="0def07cf-7dac-46b3-8612-af3820738b12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0def07cf-7dac-46b3-8612-af3820738b12")) {                    Plotly.newPlot(                        "0def07cf-7dac-46b3-8612-af3820738b12",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (NonProbempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.GFLOPS*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_16mpi_4omp.GFLOPS*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.GFLOPS*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_32mpi_2omp.GFLOPS*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.GFLOPS*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_56mpi_1omp.GFLOPS*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.GFLOPS*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_64mpi_1omp.GFLOPS*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-Fused vs AVX-Fused (Non-Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="37790fa3-8659-4683-9477-895364be32f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37790fa3-8659-4683-9477-895364be32f9")) {                    Plotly.newPlot(                        "37790fa3-8659-4683-9477-895364be32f9",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## MACRO-Fused vs AVX-Fused (NonProbempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.BAND*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_16mpi_4omp.BAND*(dfn2AvxFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.BAND*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_32mpi_2omp.BAND*(dfn2AvxFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.BAND*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_56mpi_1omp.BAND*(dfn2AvxFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.BAND*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxFusNonProb_64mpi_1omp.BAND*(dfn2AvxFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-Fused vs AVX-Fused (NonProbempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="ea87f2ba-2131-4b36-8f46-98b7d7b7f8d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea87f2ba-2131-4b36-8f46-98b7d7b7f8d2")) {                    Plotly.newPlot(                        "ea87f2ba-2131-4b36-8f46-98b7d7b7f8d2",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# # MACRO-Non-Fused vs AVX-Non-Fused

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_16mpi_4omp.GFLOPS*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_16mpi_4omp.GFLOPS*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))




# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_32mpi_2omp.GFLOPS*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_32mpi_2omp.GFLOPS*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_56mpi_1omp.GFLOPS*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_56mpi_1omp.GFLOPS*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_64mpi_1omp.GFLOPS*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_64mpi_1omp.GFLOPS*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="1c9fc819-752e-46eb-bb26-dd4c2e9fd42b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c9fc819-752e-46eb-bb26-dd4c2e9fd42b")) {                    Plotly.newPlot(                        "1c9fc819-752e-46eb-bb26-dd4c2e9fd42b",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523215
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (Probempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_16mpi_4omp.BAND*(dfn2MacNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_16mpi_4omp.BAND*(dfn2AvxNonFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_32mpi_2omp.BAND*(dfn2MacNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_32mpi_2omp.BAND*(dfn2AvxNonFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_56mpi_1omp.BAND*(dfn2MacNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_56mpi_1omp.BAND*(dfn2AvxNonFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))

# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusProb_64mpi_1omp.BAND*(dfn2MacNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


fig.add_trace(go.Scatter(x=(dfn2AvxNonFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusProb_64mpi_1omp.BAND*(dfn2AvxNonFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (Probempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="b01abc22-d915-489b-8331-64d57a452f6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b01abc22-d915-489b-8331-64d57a452f6c")) {                    Plotly.newPlot(                        "b01abc22-d915-489b-8331-64d57a452f6c",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523215
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (NonProbempi): GFLOPS

# %%
fig = go.Figure()

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_16mpi_4omp.GFLOPS*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_16mpi_4omp.GFLOPS*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_32mpi_2omp.GFLOPS*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_32mpi_2omp.GFLOPS*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))





# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_56mpi_1omp.GFLOPS*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_56mpi_1omp.GFLOPS*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_64mpi_1omp.GFLOPS*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_64mpi_1omp.GFLOPS*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))





# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (NonProbempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="076d7ac8-602d-434d-a625-fee883a62f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("076d7ac8-602d-434d-a625-fee883a62f1f")) {                    Plotly.newPlot(                        "076d7ac8-602d-434d-a625-fee883a62f1f",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523
# ...

# %% [markdown]
# ## MACRO-NonFused vs AVX-NonFused (NonProbempi): BANDWIDTH

# %%
fig = go.Figure()

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_16mpi_4omp.BAND*(dfn2MacNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_16mpi_4omp.BAND*(dfn2AvxNonFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

# 2----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_32mpi_2omp.BAND*(dfn2MacNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))


fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_32mpi_2omp.BAND*(dfn2AvxNonFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))



# 3----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_56mpi_1omp.BAND*(dfn2MacNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_56mpi_1omp.BAND*(dfn2AvxNonFusNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))



# 4----
fig.add_trace(go.Scatter(x=(dfn2MacNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNonFusNonProb_64mpi_1omp.GFLOPS*(dfn2MacNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNonFusNonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2AvxNonFusNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2AvxNonFusNonProb_64mpi_1omp.BAND*(dfn2AvxNonFusNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='AvxNonFusNonProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO-NonFused vs AVX-NonFused (NonProbempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="70ed3b81-9f62-45f6-98d2-2764b0595685" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70ed3b81-9f62-45f6-98d2-2764b0595685")) {                    Plotly.newPlot(                        "70ed3b81-9f62-45f6-98d2-2764b0595685",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacNonFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,3523
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (NonProbempi): GFLOPS

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.GFLOPS*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_16mpi_4omp.GFLOPS*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.GFLOPS*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_32mpi_2omp.GFLOPS*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))



# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.GFLOPS*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_56mpi_1omp.GFLOPS*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.GFLOPS*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_64mpi_1omp.GFLOPS*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                          line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))



# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (NonProbempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="8e522f61-05e4-44de-8d6b-e3ef74fa2f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e522f61-05e4-44de-8d6b-e3ef74fa2f1f")) {                    Plotly.newPlot(                        "8e522f61-05e4-44de-8d6b-e3ef74fa2f1f",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (NonProbempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_16mpi_4omp.BAND*(dfn2MacFusNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_16mpi_4omp.BAND*(dfn2MacNewgeoNonProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----
fig.add_trace(go.Scatter(x=(dfn2MacFusNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusNonProb_32mpi_2omp.BAND*(dfn2MacFusNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusNonProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_32mpi_2omp.BAND*(dfn2MacNewgeoNonProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))



# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_56mpi_1omp.BAND*(dfn2MacFusnonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_56mpi_1omp.BAND*(dfn2MacNewgeoNonProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))


# 4----

fig.add_trace(go.Scatter(x=(dfn2MacFusnonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusnonProb_64mpi_1omp.BAND*(dfn2MacFusnonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusnonProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoNonProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoNonProb_64mpi_1omp.BAND*(dfn2MacNewgeoNonProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoNonProb_64mpi_1omp',
                          line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (NonProbempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="30adecdd-b1be-4ad5-b004-d80214bef3a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30adecdd-b1be-4ad5-b004-d80214bef3a6")) {                    Plotly.newPlot(                        "30adecdd-b1be-4ad5-b004-d80214bef3a6",                        [{"line":{"color":"magenta","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusNonProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,35232153
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (Probempi): GFLOPS

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.GFLOPS*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_16mpi_4omp.GFLOPS*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----

fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.GFLOPS*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_32mpi_2omp.GFLOPS*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))




# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.GFLOPS*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_56mpi_1omp.GFLOPS*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))




# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.GFLOPS*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_64mpi_1omp.GFLOPS*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))

# Adding a vertical line
fig.add_vline(x=80e6, line_width=3, line_dash="dash", line_color="green")
# fig.add_hline(y=1024, line_width=3, line_dash="dash", line_color="red")

# Add annotation
fig.add_annotation(
    x='80e6'
    , y=130
    , text=f'LLC Size Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (Probempi)" GFlops Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='GFLOPs/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="24bdb7b5-4402-45e8-bfa8-60f1bd08e226" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24bdb7b5-4402-45e8-bfa8-60f1bd08e226")) {                    Plotly.newPlot(                        "24bdb7b5-4402-45e8-bfa8-60f1bd08e226",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...

# %% [markdown]
# ## MACRO OLD (Fused) vs NEW Geometry (Probempi): BANDWIDTH

# %%
fig = go.Figure() 

# 1---
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_16mpi_4omp.BAND*(dfn2MacFusProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_16mpi_4omp',
                         line=dict(color='darkcyan',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))

fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_16mpi_4omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_16mpi_4omp.BAND*(dfn2MacNewgeoProb_16mpi_4omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_16mpi_4omp',
                         line=dict(color='magenta',width=3),
                         marker=dict(symbol='hexagon',size=9, line=dict(color='yellow',width=1))))


# 2----

fig.add_trace(go.Scatter(x=(dfn2MacFusProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_32mpi_2omp.BAND*(dfn2MacFusProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_32mpi_2omp',
                         line=dict(color='royalblue',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_32mpi_2omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_32mpi_2omp.BAND*(dfn2MacNewgeoProb_32mpi_2omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_32mpi_2omp',
                         line=dict(color='sandybrown',width=3),
                         marker=dict(symbol='diamond',size=5,line=dict(color='MediumPurple',width=2))))




# 3----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_56mpi_1omp.BAND*(dfn2MacFusProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_56mpi_1omp',
                         line=dict(color='darkblue',width=3),
                         marker=dict(symbol='circle',size=7, line=dict(color='tomato',width=2))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_56mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_56mpi_1omp.BAND*(dfn2MacNewgeoProb_56mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_56mpi_1omp',
                         line=dict(color='cyan',width=3),
                         marker=dict(symbol='circle',size=7,line=dict(color='Purple',width=2))))




# 4----
fig.add_trace(go.Scatter(x=(dfn2MacFusProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacFusProb_64mpi_1omp.BAND*(dfn2MacFusProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacFusProb_64mpi_1omp',
                         line=dict(color='red',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))
fig.add_trace(go.Scatter(x=(dfn2MacNewgeoProb_64mpi_1omp.Dirc_Data_Mov*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         y=(dfn2MacNewgeoProb_64mpi_1omp.BAND*(dfn2MacNewgeoProb_64mpi_1omp.MPI_size/2)), 
                         mode='lines+markers', 
                         name='MacNewgeoProb_64mpi_1omp',
                         line=dict(color='blue',width=3),
                         marker=dict(symbol='star',size=7, line=dict(color='black',width=1))))


# Adding vertical and horizontal lines 
fig.add_vline(x=80e6, line_width=3, line_dash="dot", line_color="green")
fig.add_hline(y=153, line_width=3, line_dash="dash", line_color="red")

# Add annotation with arrow
fig.add_annotation(
    x='80e6'
    , y=280
    , text=f'LLC Size Per Node: 80M'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="purple", family="Sans Serif")
    , align="left"
    ,)

fig.add_annotation(
    x='130e6'
    , y=155
    , text=f'Max Bandwidth Per Node'
    , yanchor='bottom'
    , showarrow=False
    , arrowhead=1
    , arrowsize=1
    , arrowwidth=2
    , arrowcolor="#636363"
    , ax=-20
    , ay=-30
    , font=dict(size=12, color="orange", family="Sans Serif")
    , align="left"
    ,)



fig.update_layout(title='"MACRO OLD (Fused) vs NEW Geometry (Probempi)" Bandwidth Measurement',
                  xaxis_title='Dirc_Data_Mov', yaxis_title='Bandwidth/Node', 
                  xaxis=dict(ticks="outside"),  
                  yaxis=dict(ticks="outside"),
                  legend=go.layout.Legend(bordercolor="black",borderwidth=1))
# Out:
# <div>                            <div id="5ff1e978-c58e-4508-913c-0195e5e4a395" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ff1e978-c58e-4508-913c-0195e5e4a395")) {                    Plotly.newPlot(                        "5ff1e978-c58e-4508-913c-0195e5e4a395",                        [{"line":{"color":"darkcyan","width":3},"marker":{"line":{"color":"yellow","width":1},"size":9,"symbol":"hexagon"},"mode":"lines+markers","name":"MacFusProb_16mpi_4omp","x":[50331648.0,62914560.0,75497472.0,88080384.0,100663296.0,113246208.0,125829120.0,138412032.0,150994944.0,163577856.0,176160768.0,188743680.0,201326592.0,213909504.0,226492416.0,239075328.0,251658240.0,264241152.0,276824064.0,289406976.0,301989888.0,314572800.0,327155712.0,339738624.0,352321536.
# ...
